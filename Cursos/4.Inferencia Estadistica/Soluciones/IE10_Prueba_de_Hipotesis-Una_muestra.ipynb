# %% [markdown]
# # **Inferencia estadística**
# # IE10. Prueba de Hipótesis - Una muestra - SOLUCION

# %% [markdown]
# ## <font color='blue'>__Bibliografía__</font>
# * Applied Statistics and Probability for Engineers. Douglas C. Montgomery, George C. Runger, 2013.
#
# * Estadística para Administración y Economía. Paul Newbold, William L. Carlson y Betty Thorne, 2013.
#
# * Estadística Aplicada a los Negocios y la Economía. Allen L. Webster, 2000.
#
# * Statistical methods for research workers. R.A. Fisher, 1925.
#
#
# ## <font color='blue'>__Lecturas__</font>
# * The One-Sample t-Test. Statistics knowledge portal. [JMP](https://www.jmp.com/en_sg/statistics-knowledge-portal/t-test/one-sample-t-test.html)
#
# * Selva Prabhakaran (2020). One Sample T Test – Clearly Explained with Examples. Machine Learning Plus. [ML+](https://www.machinelearningplus.com/statistics/one-sample-t-test/)
# * PRUEBA Z. [Euclides.org](https://euclides.org/prueba-z/)

# %% [markdown]
# ## <font color='blue'>**Definiciones**</font>
#
# Una hipótesis estadística es una afirmación o proposición respecto a alguna característica de una población, generalmente fundamentada sobre un parámetro de la misma. Contrastar una hipótesis es comparar las predicciones con la realidad que observamos ocurrida en una muestra. Si dentro del margen de error que estamos dispuestos a admitir, hay coincidencia, aceptaremos la hipótesis y en caso contrario la rechazaremos.
#
# 1. La hipótesis emitida se suele designar por $𝑯_𝟎$ y se llama **Hipótesis nula**. Lo de “nula” viene de que partimos del supuesto que las diferencias entre el valor verdadero del parámetro y su valor hipotético, en realidad, no son tales sino debidas al azar, es decir, no hay diferencia entre ambos, o dicho de otra forma la diferencia es nula.
#
# 2. La hipótesis contraria se designa por $𝑯_𝟏$  y se llama **Hipótesis alternativa**.

# %% [markdown]
# ### <font color='blue'>**Hipótesis nula**</font>
#
#
# La hipótesis nula (denotada por $H_0$) es la afirmación de que el valor de un parámetro de la población (media, proporción o desviación estándar) es igual a un valor aseverado.
#
# Las siguientes son hipótesis nulas típicas:
# <br>
# <br>
# 1. $H_0: \quad \mu = 37$
# 2. $H_0: \quad p = 0.5$
# 2. $H_0: \quad \sigma = 15$
# <br>
# <br>
#
# La hipótesis nula se aprueba en forma directa, en el sentido que __se supone que es verdadera__, y llegamos a una conclusión de rechazar $H_0$ o no rechazar $H_0$.

# %% [markdown]
# ### <font color='blue'>**Hipótesis alternativa**</font>
#
# La hipótesis alternativa (denotada por $H_1$) es la afirmación de que el parámetro tiene un valor que difiere de la hipótesis nula. Los símbolos que emplea la hipótesis alternativa son: $\lt$, $\gt$ o bien $\ne$.
# <br>
# <br>
# $$
# \begin{align*}
# \text{Medias}: &\quad H_1:\mu \gt 37 \quad H_1: \mu \lt 37 &\quad H_1: \mu \neq 37\\
# \text{Proporciones}: &\quad H_1:p \gt 0.5 \quad H_1: p \lt 0.5 &\quad H_1: p \neq 0.5 \\
# \text{Desviación estándar}: &\quad \underbrace{H_1:\sigma \gt 15 \quad H_1: \sigma \lt 15 }_{Unilaterales\\(una \, cola)}&\quad \underbrace{H_1: \sigma \neq 15}_{Bilaterales\\(dos \, colas)}
# \end{align*}
# $$
# <br>
# <br>
# Si está realizando un estudio y desea emplear una prueba de hipótesis para sustentar una aseveración, esta debe redactarse de tal manera que se convierta en la hipótesis alternativa. Esto quiere decir, que su aseveración debe expresarse utilizando solo estos símbolos $\lt$, $\gt$ o bien $\ne$.

# %% [markdown]
# ### <font color='blue'>**Ejemplos**</font>
#
# 1. Sospechamos que las bolsas de frutos secos de 100 gramos, realmente no pesan 100 gramos. Para contrastar esta hipótesis plantearíamos:
#
# $$H_0: \mu = 100$$
# $$H_1: \mu \neq 100$$
#
# 2. Pensamos que la proporción de gente que votó al partido A en las elecciones (35%) ahora es inferior ya que no lo han hecho muy bien. Para contrastar esta hipótesis:
#
# $$H_0:p \geq 0.35 $$
# $$H_1:p < 0.35 $$
#
# 3. Estaría contento de comprobar que no pueden demostrar que mi media de notas ha bajado de 6.2 como parecen indicar los últimos exámenes. Para contrastar esta hipótesis:
#
# $$H_0:\mu \ge 6.2 $$
# $$H_1:\mu \lt 6.2 $$
# <br>
# ### __Contraste de hipótesis__
# Se formula la hipótesis sobre la población (e.g., $\mu$, $p$, $\sigma$, etc.).  Entonces las conclusiones sobre la validez de la hipótesis se basarán en la información de una muestra (e.g.,. $\bar{x}$, $\hat{p}$, $S$, etc).
#
# La realización de un contraste de hipótesis __no consiste en__ dicidir cuál de las dos hipótesis ($H_0$ o $H_1$) es más creible, sino en decidir si la muestra proporciona o no suficiente evidencia para descartar $H_0$. Mientras no tengamos suficiente evidencia para aceptar $H_1$ tendremos que creernos que $H_0$ es cierta.

# %% [markdown]
# ### <font color='green'>Actividad 1</font>
#
# Siguiendo los ejemplos anteriores, defina tres ejemplos de hipotesis identificando $H_0$ y $H_1$.

# %% [markdown]
# <font color='green'>Tu respuesta aquí ...</font>
#
# Ejemplo 1:
#
# Supongamos que estás investigando si un nuevo medicamento reduce la presión arterial en pacientes con hipertensión.
#
# Hipótesis nula (H0): La media de la presión arterial en pacientes tratados con el nuevo medicamento es igual a la media de la presión arterial en pacientes no tratados.
#
# Hipótesis alternativa (H1): La media de la presión arterial en pacientes tratados con el nuevo medicamento es diferente de la media de la presión arterial en pacientes no tratados.
#
# H0: μ_tratado = μ_no_tratado
#
# H1: μ_tratado ≠ μ_no_tratado
#
#
#
# Ejemplo 2:
#
# Supongamos que estás investigando si un nuevo fertilizante aumenta la producción de maíz en una granja.
#
#
# Hipótesis nula (H0): La media de la producción de maíz utilizando el nuevo fertilizante es igual a la media de la producción de maíz sin utilizar el nuevo fertilizante.
#
# Hipótesis alternativa (H1): La media de la producción de maíz utilizando el nuevo fertilizante es diferente de la media de la producción de maíz sin utilizar el nuevo fertilizante.
#
# H0: μ_con_fertilizante = μ_sin_fertilizante
#
# H1: μ_con_fertilizante ≠ μ_sin_fertilizante
#
# Ejemplo 3:
#
# Supongamos que estás investigando si la proporción de estudiantes que aprueban un examen es menor en una nueva metodología de enseñanza en comparación con la metodología tradicional.
#
#
# Hipótesis nula (H0): La proporción de estudiantes que aprueban el examen utilizando la nueva metodología es igual a la proporción de estudiantes que aprueban el examen utilizando la metodología tradicional.
#
# Hipótesis alternativa (H1): La proporción de estudiantes que aprueban el examen utilizando la nueva metodología es menor que la proporción de estudiantes que aprueban el examen utilizando la metodología tradicional.
#
# H0: p_nueva_metodologia = p_metodologia_tradicional
#
# H1: p_nueva_metodologia < p_metodologia_tradicional

# %% [markdown]
# <font color='green'>Fin Actividad 1</font>

# %% [markdown]
# ## <font color='blue'>**Estadístico de prueba**</font>
# El **estadístico de prueba**, es un valor que se utiliza para tomar la decisión sobre la hipótesis nula y se calcula convirtiendo el **estadístico muestral** (tales como la media muestral $\bar{x}$, o la proporción muestral $\hat{p}$) en una puntuación (tales como los $Z$ o $t$ _scores_), bajo el supuesto que la hipótesis nula es verdadera. Este tipo de tests, utilizará puntuaciones $Z$ o $t$ dependiendo del tamaño de la muestra y de si $\sigma$, (desviación estándar poblacional) es conocida.
#
# ![Estadísticos de prueba](https://drive.google.com/uc?export=view&id=1ZOllppXNDN0JryHIgpSJQHnadPpn5oYH)

# %% [markdown]
# ### <font color='blue'>**Prueba $Z$**</font>
#
# La __prueba $Z$__, es un tipo de prueba paramétrica que se utiliza para determinar el grado de significatividad estadística de las diferencias entre las medias de dos conjuntos de datos. Se utiliza cuando las muestras son amplias (de más de 30 individuos aproximadamente), independientes (esto es, no correlacionadas) y con $\sigma$ conocido. Opera con la media, la desviación típica y el número de individuos de cada muestra. Una vez calculado el valor de $Z$, se comparará con el valor crítico de $Z$ obtenido de una curva de distribución normal. La hipótesis nula sostiene que la diferencia entre medias no es significativa y será rechazada si el valor obtenido en la prueba Z sobrepasa el valor crítico.
#
# Para determinar si se acepta o rechaza la hipótesis $H_0$, se define una valor de $Z$ crítico. Este valor puede ser sobre una cola o ambas colas como muestra la figura siguiente.
#
# <img alt="Region de rechazo" title="Region de rechazo" src="https://drive.google.com/uc?export=view&id=11-v9wIvygISMoxeIEMqabzbxDgLqMBsH" width=850px>
#
#
# Las colas en una distribución corresponden a las regiones extremas, limitadas por los valores críticos:
#
#
# <br><br>
# __Valores críticos para $\mu$ y $p$ cuando $\sigma$ es conocida__
# <br><br>
# <img alt="Valores críticos mu y p" title="Valores críticos mu y p" src="https://drive.google.com/uc?export=view&id=1xyvF9OIrcRss-WMesgcl0LfFIDP2BqQW" width=850px>
#
#
# En la siguiente imagen, se calcula el valor critico para distintos rangos de confianza, $\alpha= 10\%, 5\%, \dots$, etc., para el caso de una y dos colas.
#
# <img alt="Region de rechazo" title="Region de rechazo" src="https://drive.google.com/uc?export=view&id=18qtyKuMS7tcNuPqpleXQ8onP4WCrPkOT" width=850px>
# <br><br>

# %% [markdown]
# ### <font color='blue'>**Valor-P (P-Value)**</font>
# El __nivel crítio $P$__ (o __Valor-P__), es el nivel de significación __más pequeño__ para el que la muestra obtenida obligaría a rechazar la hipótesis nula. En términos simples, el __Valor-P__ nos ayuda a diferenciar resultados que son producto del azar del muestreo, de resultados que son estadísticamente significativos.
# * El Valor-p es la probabilidad (calculada bajo $H_0$) de obtener un resultado que sea menos compatible con $H_0$ que el resultado obtenido con la muestra.
# * El Valor-P depende de la muestra.
# * Puede considerarse como el apoyo que la hipótesis nula recibe de las observaciones de la muestra:
#  * Si el Valor-P e __menor__ que el nivel de significación ($\alpha$) prefijado, podemos decir que tenemos un resultado estadísticamente significativo y que el apoyo a $H_0$ es escaso y, por tanto, $H_0$ debe rechazarse.
#  * Si el Valor-P es __mayor o igual__ que el nivel de significación ($\alpha$) prefijado, el apoyo a $H_0$ es suficiente y, por tanto, $H_0$ __NO__ debe rechazarse.
# * El Valor-P, al ser una probabilidad, oscila entre 0 y 1.
#
#
# El siguiente es el procedimiento para el cálculo de los Valores-P
#
# <img alt="Cálculo Valores P" title="Cálculo Valores P" src="https://drive.google.com/uc?export=view&id=1gMTQ0dlCToiFCWWwxAFcX6YHcgs8zP5k" width=850px>
# <br><br>

# %% [markdown]
# ### <font color='blue'>**Nivel de significación ($\alpha$)**</font>
#
# Los niveles de significación son el complemento al intervalo de confianza de una distribución y se utilizan para contrastar la hipótesis nula ($H_0$) en una prueba de inferencia estadística. En otras palabras, los niveles de significación son las probabilidades que dejamos fuera del intervalo de confianza de una distribución y nos ayudan a determinar si el estadístico de contraste está en zona de rechazo o no.
#
# Los valores típicos utilizados para un nivel de significación son $0.05$ y $0.01$. Ronald Fisher decía:
#
# > “Un fenómeno es demostrable experimentalmente cuando se conoce como conducir un experimento que raramente falla para darnos un resultado estadísticamente significativo”.
#
# De acuerdo con esta lógica se entiende que, con un nivel de significación del $5\%$, en promedio cinco de cada 100 veces que la hipótesis nula sea cierta se rechazará por azar. Es decir, 5 de cada 100 veces que rechazamos la hipótesis nos estaremos equivocando, pues se asume que es cierta y la prueba no demuestra ni su falsedad ni su certeza.
#
# <br>

# %% [markdown]
# ### <font color='blue'>**Criterios de decisión**</font>
#
# El procedimiento convencional de prueba de hipótesis requiere que __siempre probemos la hipótesis nula__, de manera que nuestra conclusión inicial siempre será una de las siguientes:
#
# 1. Rechazo la hipótesis nula.
# 2. No rechazo la hipótesis nula.
#
# La decisión de rechazar o no una hipótesis nula, se puede realizar a través de dos métodos; el __Método clásico__ o por __Valor P__:
#
# __Método clásico__
# <br>
# * __Rechazo__ $H_0$  si el estadístico de prueba ($Z$ o $t$) cae dentro de la Región crítica.
#
# * __No Rechazo__ $H_0$  si el estadístico de prueba __NO__ cae dentro de la Región crítica.
#
# __Valor P__
# <br>
# * __Rechazo__ $H_0$  si el valor $P \le \alpha$, donde $\alpha$ es el nivel de significancia.
# * __No Rechazo__ $H_0$  si el valor $P \gt \alpha$
# <br><br>
#
# ### Entonces,  considerando el método clásico, rechazamos $H_0$ si ...
#
# <img alt="Rechazo H nula" title="Rechazo H nula" src="https://drive.google.com/uc?export=view&id=14BlLMoupsYjAFI73JXqzyu2pj6k3yude" width=850px>

# %% [markdown]
# ### <font color='blue'>**Ejemplo: Hipótesis para la media  ($\sigma$ conocido)**</font>
#
#
# Una manada de 1.500 novillos fue alimentada con un grano especial rico en proteínas durante un mes. Se pesó una muestra aleatoria de 29 y habían ganado un promedio de 7.7 libras. Si la desviación estándar de la ganancia de peso para todo el rebaño es 7.1, pruebe la hipótesis de que la ganancia de peso promedio por novillo durante el mes fue de más de 5 libras.
#
# 1. Hipotesis nula, $H_0:\mu = 5$
# 2. Hipótesis alternativa, $H_1:\mu > 5$
#
# Vamos a calcular $Z$:
#
# $$Z = \frac{7.7 - 5}{\frac{7.1}{\sqrt{29}}} = 2.049$$
#
# Si pedimos un valor de 5% de significación, estonces si vamos a la primera tabla del diagrama vemos que para el 5% de significancia necesitamos un z de 1.645, por lo tanto como nuestro z es mayor que 1.645, se rechaza la hipotesis nula, con lo cual hubo ganancia de peso, estimada con 5% de significancia.

# %% [markdown]
# ### <font color='green'>Actividad 2</font>
# ### Hipótesis para la media  ($\sigma$ conocido)
#
# Se desea contrastar con un nivel de significación del 5 % la hipótesis de que “la talla media de los hombres de 18 o más años de un país es igual a 180”. Suponiendo que la desviación estándar de las tallas en la población es 4, contraste dicha hipótesis frente a la alternativa de que es distinta.
#
# Los datos constituyen una muestra de $n=15$ hombres seleccionados al azar, cuyas alturas son: 167, 167, 168, 168, 168, 169, 171, 172, 173, 175, 175, 175, 177, 182, 195.
#
# $𝑋$: Altura de los hombres mayores o igual a 18 años<br>
# $X \sim (\mu, 4)$
#
# 1. Calcular estadisticos muestra
# 2. Definir hipótesis
# 3. Definir tipo de prueba a aplicar
# 4. Calcular Z crítico
# 5. Calcular estadístico de prueba
# 6. Definir regla decisión
# 7. Calcular valor-p
# 8. Interprete y concluya
#
# Notas:
# - Desarróllelo manualmente
# - Impleméntelo en Python

# %% [markdown]
# #### Pasos
# ## Paso 1: Calcular estadísticos de muestra
#
# La media muestral x_ se calcula como la suma de todas las alturas dividida por el número total de muestras.
#
#
# ![imagen.png](data:image/png;base64,...)
#
#
#
#
# ![imagen.png](data:image/png;base64,...)
#
#
#
# ## Paso 2: Definir hipótesis
#
# La hipótesis nula (H0) y la hipótesis alternativa (H1) se formulan de la siguiente manera:
#
# Hipótesis nula (H0): μ=180
#
# Hipótesis alternativa (H1): μ<>180
#
# ## Paso 3: Definir tipo de prueba a aplicar
#
# Dado que se busca contrastar si la media poblacional es distinta de 180, se utilizará una prueba de dos colas.
#
# ## Paso 4: Calcular Z crítico
#
# Para un nivel de significancia del 5%, el valor crítico de Z se obtiene a partir de la distribución normal estándar. Como es una prueba de dos colas, necesitamos encontrar el valor de Z que acumula el 2.5% en la cola inferior y el 97.5% en la cola superior. Esto da como resultado un valor crítico de Z de aproximadamente ± 1.96
#
#
#
# ## Paso 5: Calcular estadístico de prueba
#
# El estadístico de prueba (Z) se calcula utilizando la fórmula:
#
# ![imagen.png](data:image/png;base64,...)
#
#
# Donde:
#
# x_   es la media muestral.
#
# μ es la media poblacional bajo la hipótesis nula.
#
# σ es la desviación estándar conocida de la población.
#
# n es el tamaño de la muestra.
#
#
# ## Paso 6: Definir regla de decisión
#
# Si el valor absoluto del estadístico de prueba ∣Z∣ es mayor que el valor crítico de Z (±1.96), rechazamos la hipótesis nula. En caso contrario, no tenemos suficiente evidencia para rechazar la hipótesis nula.
#
# ## Paso 7: Calcular valor-p
#
# El valor-p se calcula utilizando la distribución normal estándar y se refiere a la probabilidad de obtener un estadístico de prueba al menos tan extremo como el observado, bajo la suposición de que la hipótesis nula es cierta.
#
# ## Paso 8: Interpretar y concluir
#
# Si el valor-p es menor que el nivel de significancia (0.05 en este caso), rechazamos la hipótesis nula en favor de la hipótesis alternativa.

# %%
# Tu código aquí ...

# Paso 1: Calcular estadísticos de muestra
muestras = [167, 167, 168, 168, 168, 169, 171, 172, 173, 175, 175, 175, 177, 182, 195]
n = len(muestras)
media_muestral = sum(muestras) / n

# Paso 2: Definir hipótesis
mu = 180

# Paso 3: Definir tipo de prueba a aplicar
# Es una prueba de dos colas, por lo que utilizaremos el valor crítico Z de ±1.96

# Paso 4: Calcular Z crítico
z_critico = 1.96

# Paso 5: Calcular estadístico de prueba
sigma = 4
z = (media_muestral - mu) / (sigma / (n ** 0.5))

# Paso 6: Definir regla de decisión
if abs(z) > z_critico:
    decision = "Rechazar H0"
else:
    decision = "No rechazar H0"

# Paso 7: Calcular valor-p
import scipy.stats as stats

valor_p = 2 * (1 - stats.norm.cdf(abs(z)))

# Paso 8: Interpretar y concluir
nivel_significancia = 0.05

if valor_p < nivel_significancia:
    conclusion = "Se rechaza la hipótesis nula en favor de la alternativa."
else:
    conclusion = "No hay suficiente evidencia para rechazar la hipótesis nula."

# Imprimir resultados
print(f"Media muestral: {media_muestral}")
print(f"Estadístico de prueba (Z): {z}")
print(f"Valor-p: {valor_p}")
print(f"Decisión: {decision}")
print(f"Conclusión: {conclusion}")
# Out:
# Media muestral: 173.46666666666667
# Estadístico de prueba (Z): -6.325872798805446
# Valor-p: 2.5180524332313325e-10
# Decisión: Rechazar H0
# Conclusión: Se rechaza la hipótesis nula en favor de la alternativa.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Definir el rango para la distribución normal estándar
x = np.linspace(-8, 8, 1000)

# Calcular la densidad de probabilidad
y = stats.norm.pdf(x, 0, 1)

# Definir los puntos críticos Z
z_critico = 1.96

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Distribución Normal Estándar')
plt.fill_between(x, y, where=(x < -z_critico) | (x > z_critico), color='red', alpha=0.2)

# Etiquetar las regiones de rechazo
plt.text(z_critico + 0.1, 0.1, 'Región de Rechazo', color='red', fontsize=12)
plt.text(-z_critico - 4, 0.1, 'Región de Rechazo', color='red', fontsize=12)

# Añadir líneas verticales para z y -z
plt.axvline(z_critico, color='green', linestyle='--', label=f'z crítico ({z_critico:.2f})')
plt.axvline(-z_critico, color='green', linestyle='--')

# Añadir línea vertical para el estadístico de prueba z
# z_estadistico = -3.172
z_estadistico = -6.326
plt.axvline(z_estadistico, color='blue', linestyle='--', label=f'Estadístico de prueba (Z) ({z_estadistico:.2f})')

# Añadir etiquetas y leyenda
plt.xlabel('Valor de Z')
plt.ylabel('Densidad de Probabilidad')
plt.title('Prueba de Hipótesis')
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Definir la distribución de la media muestral bajo la hipótesis nula
media_nula = mu
desviacion_estandar = sigma / (n ** 0.5)
x = np.linspace(165, 195, 100)
y = stats.norm.pdf(x, media_nula, desviacion_estandar)

# Crear el gráfico
plt.plot(x, y, label='Distribución de la Media Muestral Bajo H0', color='blue')

# Agregar líneas y etiquetas para la media muestral y el valor crítico Z
plt.axvline(x=media_muestral, color='red', linestyle='dashed', linewidth=1, label='Media Muestral')
plt.text(media_muestral+1, 0.01, f'Media Muestral\n{round(media_muestral, 2)}', color='red')
plt.axvline(x=mu, color='green', linestyle='dashed', linewidth=1, label='Media Hipotética (mu)')
plt.axvline(x=mu+z_critico*sigma, color='purple', linestyle='dashed', linewidth=1, label='Límite superior crítico')
plt.axvline(x=mu-z_critico*sigma, color='purple', linestyle='dashed', linewidth=1, label='Límite inferior crítico')

# Añadir etiquetas y leyenda
plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución de la Media Muestral y Prueba de Hipótesis')
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# cargar data de la muestra de 15 hombres seleccionados al azar

altura= (167, 167, 168, 168, 168, 169, 171, 172, 173, 175, 175, 175, 177, 182, 195)

# se conoce el sigma poblacional Sigma = 4
sigma = 4

# 1.  Calcular estadisticos muestra
xbar = np.mean(altura)
S = np.std(altura, ddof=1) # desv. std insesgada no es necesaria utilizarla dado que se conoce Sigma
n = np.size(altura)

print(f'Sigma población                     : {sigma:4.2f}')
print(f'Media muestral (x barra)            : {xbar:4.2f}')
print(f'Desviación estándar insesgada (S)   : {S:4.2f}')
print(f'Tamaño muestra                      : {n}')
# Out:
# Sigma población                     : 4.00
# Media muestral (x barra)            : 173.47
# Desviación estándar insesgada (S)   : 7.36
# Tamaño muestra                      : 15

# %%
# 2. Definir hipótesis a contrastar (prueba bilateral - 2 colas)
#    H0:   Mu = 180
#    H1:   Mu ≠  180

alpha = 0.05 # Significancia al 5%
Mu = 180

# 3. Como n < 30 y sí se conoce Sigma, aplicaremos Z
#    asumimos que datos se distribuyen normal X-N(mu, 4)

# 4) buscar valor critico de Z
z_critico_1 = stats.norm.ppf((alpha/2))    # 2 colas, en esta forma en Python encontramos el valor critico en el Z-test.
z_critico_2 = stats.norm.ppf(1 - (alpha/2))# 2 colas, en esta forma en Python encontramos el valor critico en el Z-test.

print(f'Z crítico 1: {z_critico_1:4.2f}')
print(f'Z crítico 2: {z_critico_2:4.2f}')


# 5. calcular estadístico de prueba Z
Z =  (xbar - Mu) / (sigma / np.sqrt(n)) # utilizar sigma población
print(f'Z: {Z:4.2f}')


# 6. Definir regla decisión
#    no rechazar H0 si: -Zcritico <= Z <= Z crítico
#    rechazar H0 si:  Z < -Zcritico  o  Z > Zcritico


# 7. calcular valor-p
pvalue = (stats.norm.cdf(Z)) # Z de prueba se encuentra en cola izquierda
print(f'Valor-p: {pvalue*2: 8.6e}')
# Out:
# Z crítico 1: -1.96
# Z crítico 2: 1.96
# Z: -6.33
# Valor-p:  2.518052e-10

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# ### <font color='blue'>**T-Test**</font>
#
#
# __Test-T__ es una prueba en la que el estadístico utilizado tiene una distribución __t de Student__ si la hipótesis nula es cierta. Se aplica cuando la población estudiada sigue una distribución normal, pero el tamaño muestral es demasiado pequeño como para que el estadístico en el que está basada la inferencia esté normalmente distribuido, utilizándose una estimación de la desviación típica en lugar del valor real.
#
# Para calcular __t__ se utiliza la siguiente formula:
#
# $$ t = \frac{\bar{x} - \mu}{\frac{S}{\sqrt{n}}}$$
#
# Donde $S$ es la la desviación estándar muestral.
#
# <br><br>
# __Valores críticos para $\mu$ y $p$ cuando $\sigma$ es conocida__
# <br>
# <img alt="Valores críticos mu y p" title="Valores críticos mu y p" src="https://drive.google.com/uc?export=view&id=1ZVwyLcY-uNPtTOHe2UNLyh5o-x3adlea" width=850px>

# %% [markdown]
# ### <font color='blue'>**Ejemplo: Hipótesis para la media  ($\sigma$ desconocido)**</font>
# ### Rentabilidad fondos de inversión
#
# Sea X la variable ”rentabilidad de cierto tipo de fondos de inversión tras una apreciación fuerte del Euro con respecto al Dólar”. Se considera que la media de esta variable es 15. Un economista afirma que dicha rentabilidad media ha variado, por lo que lleva a cabo un estudio en las condiciones reseñadas anteriormente, sobre una muestra de 9 fondos cuya media muestral resulta ser de 15.308 y cuya varianza muestral es 0.193.
#
# 1. Especificando las hipótesis necesarias, contrastar la afirmación del economista al 5%.
#
# 2. A partir del resultado de punto 1, razonar si el intervalo de confianza para la media al 95% contendrá o no al valor 15.

# %%
import numpy as np

# 1.  calcular estadisticos muestra
xbar = 15.308
S2 = 0.193 # varianza muestral
S = np.sqrt(S2) # desv. std muestral insesgada (asumimos)
n = 9

print(f'Xbarra:         {xbar:4.2f}')
print(f'S:              {S:4.2f}')
print(f'Tamaño muestra: {n}')


# 2. Definir hipótesis a contrastar (prueba bilateral - 2 colas)
#    H0:   Mu = 15
#    H1:   Mu ≠ 15

# 3. como n < 30 y no se conoce Sigma, aplicaremos T Student
alpha = 0.05
mu = 15

# 4. calcular valor crítico de T
#    n-1 grados de libertad, donde n corresponde al número de la muestra y 2 colas
Tcritico = stats.t.ppf(1-(alpha/2), df=(n-1))
print(f'T crítico: {Tcritico:4.2f}')


# 5. calcular Estadistico de prueba t
t =  (xbar - mu) / (S / np.sqrt(n))
print(f't: {t:4.2f}')

# 6. Define Regla de decision
#    no rechaza H0 si: -Tcritico <= t <= Tcritico
#    rechazar H0 si:  t < -Tcritico  o  t > Tcritico


# 7. calcular valor-p
pvalue = 1 - (stats.t.cdf(t, df=(n - 1)))
print(f'Valor-p: {pvalue*2:4.2f}') #2 colas
# Out:
# Xbarra:         15.31
# S:              0.44
# Tamaño muestra: 9
# T crítico: 2.31
# t: 2.10
# Valor-p: 0.07

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Definir el rango para la distribución t con 8 grados de libertad
x = np.linspace(-4, 4, 1000)
t_dist = stats.t.pdf(x, df=8)

# Definir el estadístico de prueba t
t_estadistico = 1.998

# Calcular el valor crítico
valor_critico = 2.306

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, t_dist, label='Distribución t (8 grados de libertad)')
plt.fill_between(x, t_dist, where=(x < -valor_critico) | (x > valor_critico), color='red', alpha=0.2)

# Etiquetar las regiones de rechazo
plt.text(valor_critico + 0.1, 0.05, 'Región de Rechazo', color='red', fontsize=12)
plt.text(-valor_critico - 2, 0.05, 'Región de Rechazo', color='red', fontsize=12)

# Añadir líneas verticales para t y -t
plt.axvline(valor_critico, color='green', linestyle='--', label=f'Valor crítico t ({valor_critico:.2f})')
plt.axvline(-valor_critico, color='green', linestyle='--')

# Añadir línea vertical para el estadístico de prueba t
plt.axvline(t_estadistico, color='blue', linestyle='--', label=f'Estadístico de prueba t ({t_estadistico:.2f})')

# Añadir etiquetas y leyenda
plt.xlabel('Valor de t')
plt.ylabel('Densidad de Probabilidad')
plt.title('Prueba de Hipótesis (t de Student)')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Conclusión:
#
# Como $t$ de prueba se encuentra entre $+- Tcritico$ , no se rechaza la $H_0$. No existe evidencia para afirmar que la rentabilidad ha cambiado.
#
# Al observar el valor-p , este es mayor a $\alpha=0,05$. Por tanto no se rechaza $H_0$ ya que 7 de cada 100 veces que la hipótesis nula sea cierta, será rechazada por el azar de la muestra.

# %% [markdown]
# ### <font color='green'>Actividad 3</font>
# ### Control de calidad de los dulces M&M
#
# Se adjuntan los pesos de 13 dulces M&M rojos, elegidos de una bolsa que contiene 465 M&M. A continuación se presentan los pesos (en gramos), los cuales tienen una media $\bar{x} = 0,8635$ g y una desviación estándar de $𝑆=0,0576$ 𝑔. En el empaque se afirma que el peso neto del contenido es 396,9 g. de manera que los M&M deben tener un peso medio de al menos 396,9/465=0,8535 g. para dar la cantidad anunciada. Utilice los datos muestrales con un nivel de significancia de 0,05, para probar la aseveración que hizo un gerente de producción que los M&M tienen en realidad una media mayor que 0,8535 g. de manera que los consumidores están recibiendo más que la cantidad indicada en la etiqueta.
#
# dulces = (0.751, 0.841, 0.856, 0.799, 0.966, 0.859, 0.857, 0.942, 0.873, 0.809, 0.890, 0.878, 0.905)
#
# 1. Calcular estadísticos de muestra
# 2. Definamos la hipótesis a contrastar
# 3. Identificar el estadístico que nos ayudará a definir si la hipótesis del gerente es cierta.
# 4. Calcular el estadístico de prueba con los datos entregados en la muestra de 13 datos.
# 5. Calcular el valor crítico
# 6. Describa la regla de desición
# 7. Calcular el Valor-P
# 8. Interprete y concluya

# %% [markdown]
# #### Pasos
#
# ## Paso 1: Calcular estadísticos de muestra
#
# Para los datos proporcionados:

# %% [markdown]
# #### Pasos
# ## Paso 1: Calcular estadísticos de muestra
#
# La media muestral x_ se calcula como la suma de todas las alturas dividida por el número total de muestras.
#
#
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ## Paso 2: Definir la hipótesis a contrastar
#
#
# Hipótesis nula (H0): μ≤0.8535 (Afirmación del gerente)
#
# Hipótesis alternativa (H1): μ>0.8535 (Afirmación contraria del gerente)
#
#
# ## Paso 3: Identificar el estadístico que nos ayudará a definir si la hipótesis del gerente es cierta
#
# Dado que la desviación estándar de la población no es conocida, utilizaremos la distribución t de Student. El estadístico de prueba será el t de Student.
#
# ## Paso 4: Calcular el estadístico de prueba con los datos entregados en la muestra de 13 datos
#
# El estadístico de prueba (t) se calcula utilizando la fórmula:
#
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ## Paso 5: Calcular el valor crítico
#
# Para un nivel de significancia del 5% y 12 grados de libertad (n-1), el valor crítico de t es aproximadamente 1.7823.
#
# ## Paso 6: Describir la regla de decisión
#
# Si el valor absoluto del estadístico de prueba ∣t∣ es mayor que el valor crítico de t (1.7823), rechazamos la hipótesis nula. En caso contrario, no tenemos suficiente evidencia para rechazar la hipótesis nula.
#
# ## Paso 7: Calcular el Valor-P
#
# El valor-p se calcula utilizando la distribución t de Student y se refiere a la probabilidad de obtener un estadístico de prueba al menos tan extremo como el observado, bajo la suposición de que la hipótesis nula es cierta.
#
# ## Paso 8: Interpretar y concluir
#
# Si el valor-p es menor que el nivel de significancia (0.05 en este caso), rechazamos la hipótesis nula en favor de la hipótesis alternativa.

# %%
# Tu código aquí ...
import numpy as np
import scipy.stats as stats

# Paso 1: Calcular estadísticos de muestra
muestras = np.array([0.751, 0.841, 0.856, 0.799, 0.966, 0.859, 0.857, 0.942, 0.873, 0.809, 0.890, 0.878, 0.905])
n = len(muestras)
media_muestral = np.mean(muestras)
desviacion_estandar_muestral = np.std(muestras, ddof=1)

# Paso 2: Definir la hipótesis
mu0 = 0.8535

# Paso 3: Identificar el estadístico de prueba (t de Student)
grados_libertad = n - 1

# Paso 4: Calcular el estadístico de prueba
t = (media_muestral - mu0) / (desviacion_estandar_muestral / np.sqrt(n))

# Paso 5: Calcular el valor crítico
valor_critico = stats.t.ppf(1 - 0.05, df=grados_libertad)

# Paso 6: Describir la regla de decisión
if t > valor_critico:
    decision = "Rechazar H0"
else:
    decision = "No rechazar H0"

# Paso 7: Calcular el valor-p
valor_p = 1 - stats.t.cdf(t, df=grados_libertad)

# Paso 8: Interpretar y concluir
nivel_significancia = 0.05

if valor_p < nivel_significancia:
    conclusion = "Se rechaza la hipótesis nula en favor de la alternativa."
else:
    conclusion = "No hay suficiente evidencia para rechazar la hipótesis nula."

# Imprimir resultados
print(f"Media muestral: {media_muestral}")
print(f"Estadístico de prueba (t): {t}")
print(f"Valor crítico: {valor_critico}")
print(f"Decisión: {decision}")
print(f"Valor-p: {valor_p}")
print(f"Conclusión: {conclusion}")
# Out:
# Media muestral: 0.8635384615384615
# Estadístico de prueba (t): 0.6284335832386758
# Valor crítico: 1.782287555649159
# Decisión: No rechazar H0
# Valor-p: 0.27074834066125364
# Conclusión: No hay suficiente evidencia para rechazar la hipótesis nula.

# %% [markdown]
# Conclusión: No hay suficiente evidencia para rechazar la hipótesis nula.
# Dado que el valor-p es mayor que el nivel de significancia (0.05), no hay suficiente evidencia para rechazar la hipótesis nula. Esto sugiere que no podemos afirmar con confianza que la media de los dulces M&M es mayor que 0.8535 g.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Definir el rango para la distribución t con 12 grados de libertad
x = np.linspace(-4, 4, 1000)
t_dist = stats.t.pdf(x, df=12)

# Definir el estadístico de prueba t
t_estadistico = 0.162

# Calcular el valor crítico
valor_critico = 2.179

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, t_dist, label='Distribución t (12 grados de libertad)')
plt.fill_between(x, t_dist, where=(x > valor_critico) , color='red', alpha=0.2)

# Etiquetar las regiones de rechazo
plt.text(valor_critico + 0.1, 0.05, 'Región de Rechazo', color='red', fontsize=12)


# Añadir líneas verticales para t y -t
plt.axvline(valor_critico, color='green', linestyle='--', label=f'Valor crítico ({valor_critico:.2f})')
#plt.axvline(-valor_critico, color='green', linestyle='--')

# Añadir línea vertical para el estadístico de prueba t
plt.axvline(t_estadistico, color='blue', linestyle='--', label=f'Estadístico de prueba (t) ({t_estadistico:.2f})')

# Añadir etiquetas y leyenda
plt.xlabel('Valor de t')
plt.ylabel('Densidad de Probabilidad')
plt.title('Prueba de Hipótesis (t de Student)')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Igtn9UXg6NGeRWsqh4hefQUjV0hmzlBv" width="100" align="left" title="Runa-perth">
# <br clear="left">
# Contenido opcional

# %% [markdown]
# ### <font color='green'>Actividad 4</font>
# ### Experimento genético de Mendel
#
# Cuando Gregor Mendel realizó sus famosos experimentos de hibridación con guisantes, uno de ellos dio por resultado descendencia que consistía en 428 plantas de guisantes con vainas verdes y 152 plantas guisantes con vainas amarillas. Según la teoría de Mendel, $\frac{1}{4}$ de los vástagos de guisantes debían tener vainas amarillas. Utilice un nivel de significancia de un 5%, con el método tradicional y P, para probar la aseveración de que la proporción de vástagos de guisantes con vainas es igual a $\frac{1}{4}$.
# 1. Leer el enunciado y rescatar la información, y la hipótesis para desarrollar el análisis con el método tradicional.
# 2. Definir la hipótesis a contrastar
# 3. Identificar el estadístico que nos ayudará a definir si la hipótesis sobre la proporción de vainas amarillas.
# 4. Calcular el estadístico de prueba
# 5. Calcular el valor crítico
# 6. Interprete y concluya
# 7. Calcular el Valor-P

# %% [markdown]
# ## Paso 1: Leer el enunciado y rescatar la información, y la hipótesis para desarrollar el análisis con el método tradicional.
#
# En este experimento, Mendel obtuvo un total de 580 vástagos de guisantes, de los cuales 152 tenían vainas amarillas y 428 tenían vainas verdes. Según la teoría de Mendel, se esperaba que 14 de los vástagos tuvieran vainas amarillas.
#
# ## Paso 2: Definir la hipótesis a contrastar
#
# Hipótesis nula (H0): La proporción de vástagos de guisantes con vainas amarillas es igual a 14 (como predijo Mendel).
#
# Hipótesis alternativa (H1): La proporción de vástagos de guisantes con vainas amarillas es diferente de 14.
#
# ## Paso 3: Identificar el estadístico que nos ayudará a definir si la hipótesis sobre la proporción de vainas amarillas
#
# Dado que estamos trabajando con proporciones, utilizaremos el estadístico de chi-cuadrado para este contraste de hipótesis.
#
# ## Paso 4: Calcular el estadístico de prueba
#
# El estadístico de chi-cuadrado se calcula utilizando la fórmula:
#
#
#
#
#
# Donde:
#
#
# O es el número observado de vástagos con vainas amarillas (152 en este caso).
# E es el número esperado de vástagos con vainas amarillas bajo la hipótesis nula (14 según Mendel).
#
#
# ## Paso 5: Calcular el valor crítico
#
# Dado que estamos utilizando un nivel de significancia del 5%, con un grado de libertad (ya que estamos comparando una proporción con un valor fijo), el valor crítico de chi-cuadrado es aproximadamente 3.8415.
#
# ## Paso 6: Interpretar y concluya
#
# Si el valor de chi2 calculado es mayor que el valor crítico, rechazamos la hipótesis nula. En caso contrario, no tenemos suficiente evidencia para rechazar la hipótesis nula.
#
# ## Paso 7: Calcular el Valor-P
#
# El valor-p se obtiene a partir del valor de chi2 y los grados de libertad. Indica la probabilidad de obtener un estadístico de prueba al menos tan extremo como el observado, bajo la suposición de que la hipótesis nula es cierta.

# %%
# Tu código aquí ...

import scipy.stats as stats

# Paso 2: Definir la hipótesis
O = 152
E = 14

# Paso 3: Identificar el estadístico (chi-cuadrado)
chi_cuadrado = ((O - E)**2) / E

# Paso 5: Calcular el valor crítico
valor_critico = stats.chi2.ppf(0.95, df=1)

# Paso 6: Interpretar y concluir
if chi_cuadrado > valor_critico:
    decision = "Rechazar H0"
else:
    decision = "No rechazar H0"

# Paso 7: Calcular el Valor-P
valor_p = 1 - stats.chi2.cdf(chi_cuadrado, df=1)

# Imprimir resultados
print(f"Estadístico de chi-cuadrado: {chi_cuadrado}")
print(f"Valor crítico: {valor_critico}")
print(f"Decisión: {decision}")
print(f"Valor-p: {valor_p}")
# Out:
# Estadístico de chi-cuadrado: 1360.2857142857142
# Valor crítico: 3.841458820694124
# Decisión: Rechazar H0
# Valor-p: 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la distribución de chi-cuadrado con 1 grado de libertad
x = np.linspace(0, 10, 1000)
y = stats.chi2.pdf(x, df=1)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Distribución Chi-cuadrado (1 grado de libertad)', color='blue')

# Área crítica
x_critico = np.linspace(valor_critico, 10, 1000)
y_critico = stats.chi2.pdf(x_critico, df=1)
plt.fill_between(x_critico, y_critico, color='red', alpha=0.5, label='Área Crítica (5%)')

# Línea vertical para el estadístico de prueba
#plt.axvline(chi_cuadrado, color='green', linestyle='dashed', linewidth=1, label='Estadístico de Prueba')

# Etiquetas y leyenda
plt.xlabel('Valor de chi-cuadrado')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Chi-cuadrado y Contraste de Hipótesis')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Dado que el estadístico de chi-cuadrado calculado es mucho mayor que el valor crítico, rechazamos la hipótesis nula. El valor-p es extremadamente cercano a cero, lo que indica una evidencia muy fuerte en contra de la hipótesis nula. Concluimos que la proporción de vástagos de guisantes con vainas amarillas no es igual a 14 como predijo Mendel.

# %% [markdown]
# <font color='green'>Fin Actividad 4</font>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&
# id=1Igtn9UXg6NGeRWsqh4hefQUjV0hmzlBv" width="50" align="left" title="Runa-perth">

# %% [markdown]
# ## <font color='blue'>**Errores Tipo I y II**</font>
#
# Cuando probamos la  hipótesis llegamos a la conclusión de rechazarla o no rechazarla. Tales conclusiones pueden ser correctas o incorrectas, incluso cuando se hace todo correctamente.
#
# Ninguna prueba de hipótesis es 100% cierta. Puesto que la prueba se basa en probabilidades, siempre existe la posibilidad de llegar a una conclusión incorrecta. Cuando se realiza una prueba de hipótesis, se puede cometer dos tipos de error: __tipo I__ y __tipo II__. Los riesgos de estos dos errores están inversamente relacionados y se determinan según el nivel de significancia y la potencia de la prueba. Por lo tanto, se debe determinar qué error tiene consecuencias más graves para su situación antes de definir los riesgos.
#
# <br>

# %% [markdown]
# ### <font color='blue'>**Error de tipo I**</font>
#
# Si se rechaza la hipótesis nula __$H_0$__ cuando es verdadera, se comete un __error de tipo I__. La probabilidad de cometer un __error de tipo I__ es __$\alpha$__, que es el __nivel de significancia__, el cual es establecido a priori por el investigador para la prueba de hipótesis en particular. Un $\alpha = 0.05$ indica que se está dispuesto a aceptar una probabilidad de 5% de estar equivocado al rechazar la hipótesis nula. Para reducir este riesgo, se debe utilizar un valor menor para $\alpha$. Sin embargo, usar un valor menor para alfa significa que usted tendrá menos probabilidad de detectar una diferencia si esta realmente existe.
# <br><br>
# $$\text{Nivel de significancia} = \alpha$$
#
# <br>

# %% [markdown]
# ### <font color='blue'>**Error de tipo II**</font>
#
# Cuando la hipótesis nula __$H_0$__ es falsa y no se la rechaza, se comete un __error de tipo II__. La probabilidad de cometer un error de __tipo II__ es __$\beta$__, la cual depende de la potencia de la prueba. Se puede reducir el riesgo de cometer un error de tipo II al asegurar de que la prueba tenga suficiente potencia. Para ello, debemos asegurarnos de que el tamaño de la muestra sea lo suficientemente grande como para detectar una diferencia práctica cuando esta realmente exista.
#
# $\beta$ depende principalmente del tamaño de la muestra y de la magnitud del efecto; así es que si su tópico es difícil de probar debido a lo difícil que es obtener muestras, o el efecto que busca es casi insignificante, es más probable comoter este tipo de error.
#
# La probabilidad de rechazar la hipótesis nula cuando es falsa es igual a $1 - \beta$. Este es el objetivo del investigador.  Este valor es conocido como la __potencia de la prueba__.
# <br><br>
# $$\text{Potencia de la prueba} = 1 - \beta$$
# <br><br>

# %% [markdown]
# ### <font color='blue'>**Matriz de confusión**</font>
#
# |   Decisión basada en la muestra   | $H_0$ es verdadera | $H_0$ es falsa |
# |----------------------------------------|:------------------:|:--------------:|
# | **No rechazar $H_0$**  | <font color='green'>__Decisión correcta__</font> <br>(probabilidad = $1-\alpha$)     |<font color='red'>__Error tipo II__ </font> <br> no rechazar $H_0$ cuando es falsa <br>(probabilidad = $\beta$) |
# | **Rechazar $H_0$**   | <font color='red'>__Error tipo I__</font>  <br>rechazar $H_0$ cuando es verdadera <br>(probabilidad = $\alpha$)  | <font color='green'>__Decisión correcta__</font> <br>(probabilidad = $1-\beta$)|
#
#
# ### Ejemplo de error de tipo I y tipo II
# Para entender la interrelación entre los errores de __tipo I__ y __tipo II__, y para determinar cuál error tiene consecuencias más graves para una situación específica, consideremos el siguiente ejemplo.
#
# Un investigador médico desea comparar la efectividad de dos medicamentos. Las hipótesis nula y alternativa son:
#
# >Hipótesis nula ($H_0$): $\mu_1 = \mu_2$, los dos medicamentos tienen la misma eficacia.
# >
# >Hipótesis alternativa ($H_1$): $\mu_1 \ne \mu_2$, los dos medicamentos no tienen la misma eficacia.
#
# Un __error de tipo I__ se produce si el investigador rechaza la hipótesis nula y concluye que los dos medicamentos son diferentes cuando, en realidad, no lo son. Si los medicamentos tienen la misma eficacia, el investigador podría considerar que este error no es muy grave, porque de todos modos los pacientes se beneficiarían con el mismo nivel de eficacia independientemente del medicamento que tomen. Sin embargo, si se produce un __error de tipo II__, el investigador no rechaza la hipótesis nula cuando debe rechazarla. Es decir, el investigador concluye que los medicamentos son iguales cuando en realidad son diferentes. Este error puede poner en riesgo la vida de los pacientes si se pone en venta el medicamento menos efectivo en lugar del medicamento más efectivo.
#
# Cuando realice las pruebas de hipótesis, considere los riesgos de cometer errores de tipo I y tipo II. Si las consecuencias de cometer un tipo de error son más graves o costosas que cometer el otro tipo de error, entonces elija un nivel de significancia ($\alpha$) y una potencia para la prueba ($1 - \beta$) que reflejen la gravedad relativa de esas consecuencias.
#
# ### Reflexión sobre los Errores Tipo I y II
#
# Ambos errores (tipo I y tipo II) destruyen valor a los negocios, la buena noticia es que con las pruebas de hipótesis podemos minimizarlos tomando mejores decisiones, impactando así el aprendizaje del equipo, el bienestar de los clientes y el crecimiento organizacional.
