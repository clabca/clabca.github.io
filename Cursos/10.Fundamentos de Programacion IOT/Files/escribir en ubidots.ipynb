# %%
import requests
import random
import time
TOKEN = "BBFF-SWigMmFJKDbbUzUy5RQzTIYYOGwzD5"
#cuenta clabca
#TOKEN = "BBFF-GIBTHUj83MRM0G5trb5riqvIQL7TLJ"
#cuenta ingclabra

DEVICE_LABEL = "pymaqclc1"


def main():
    url = "http://industrial.api.ubidots.com"
    url = "{}/api/v1.6/devices/{}".format(url, DEVICE_LABEL)
    headers = {"X-Auth-Token": TOKEN, "Content-Type": "application/json"}
    lat = -33.031908598618095
    lng = -71.59146678493275
    payload = {
        "temperature": {
            "value":26+random.randint(0, 5),
            "context": {
                "status": "cold",
                "set1": 23
            },
        },
    
        "humidity": random.randint(0, 100),
        "position": {"value": 1, "context": {"lat": lat, "lng": lng}}
    }
    response = requests.post(url=url, headers=headers, json=payload)
    status = response.status_code
    if status >= 400:
        print('[ERROR] No se pudo realizar el post')
    else:
        print('[INFO] Agregado correctamente')


if __name__ == '__main__':
    i = 0
    while i < 30:
        main()
        i += 1
        time.sleep(2)
# Out:
# [INFO] Agregado correctamente
# [INFO] Agregado correctamente
# [INFO] Agregado correctamente
# [INFO] Agregado correctamente
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8ed89b86b3fd> in <module>
#      41         main()
#      42         i += 1
# ---> 43         time.sleep(2)
#
# KeyboardInterrupt:

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request
