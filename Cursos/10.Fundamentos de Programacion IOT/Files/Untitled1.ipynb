# %%
Function(8, 9)
    if(a < b)
        return function (b, a)
    else if (b!=0)
        return (a + function(a,b-1))
    else
        return 0
# Out:
#   File "<ipython-input-4-a90bfea2a66f>", line 2
#     if(a < b)
#     ^
# IndentationError: unexpected indent
