# %%
for i=1 to 123
  for j=1 to i
    print i*j
  next j
next i
# Out:
#   File "<ipython-input-1-e6f84ab626d6>", line 1
#     for i=1 to 123
#          ^
# SyntaxError: invalid syntax

# %%
from types import SimpleNamespace
funcion F(a,b:entero)
  si b<=0 entonces
    retornar 0
  si no
    retornar a+F(a,b-1)
  Fin Si
fin funcion
