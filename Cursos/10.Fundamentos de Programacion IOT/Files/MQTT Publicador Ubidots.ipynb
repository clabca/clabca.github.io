# %%
pip install paho.mqtt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 99 kB 3.9 MB/s
# ...
#   Created wheel for paho.mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62132 sha256=9545c154761d613562b2caf18449da0b1944abbaac6d0d72082ce83f6f4d057b
#   Stored in directory: /root/.cache/pip/wheels/6a/48/01/c895c027e9b9367ec5470fbf371ee56e795a49ac6a19aa4c9f
# Successfully built paho.mqtt
# ...

# %%
from paho.mqtt import client as mqtt_client
import time
import json
import random



# device_label = “cualquier-identificador-etc”
# broker = "industrial.api.ubidots.com"
# port = 1883
# topic = "/v1.6/devices/{ device_label }”
# username = Ubidots TOKEN
# password = “” (en blanco)



#broker = "test.mosquitto.org"
#topic = "clabra/pucv/taller1"

broker = "industrial.api.ubidots.com"
port = 1883
topic = "/v1.6/devices/wemos-clc"
username = "BBFF-ukN5BVV6AA93DPcrnKzqc5KNItgSky"



def connect_mqtt():
    def on_connect(client, userdata, flags, return_code):
        if return_code == 0:
            print("Conectado a MQTT broker! :)")
        else:
            print("Error, codigo %d\n", return_code)

    client = mqtt_client.Client()
    client.username_pw_set(username, "")
    #client.tls_set(certfile=None,keyfile=None,cert_reqs=ssl.CERT_REQUIRED)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

def publish(client):
    counter = 0
    while True:
        time.sleep(3)
        msg = json.dumps({ "counter": counter, "time": time.time(), "temp": 20+random.randint(1, 10), "sensor_id": "WemosD1_23423" })
        result = client.publish(topic, msg)
        status = result[0]

        if status == 0:
            print("Mensaje enviado")
        else:
            print("error al enviar")
        counter += 1

def run():
    client = connect_mqtt()
    client.loop_start()
    publish(client)

# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    run()


# See PyCharm help at https://www.jetbrains.com/help/pycharm/
# Out:
# Conectado a MQTT broker! :)
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# Mensaje enviado
# ...
