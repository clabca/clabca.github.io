# %%
A = [1,2,3,2,1]

i = 0
while i <= 4:

  print('A = '+str(A[i]))

  A[i]=A[A[i]]
  print('AA= '+str(A[i]))
  print(A)
  i += 1
# Out:
# A = 1
# AA= 2
# [2, 2, 3, 2, 1]
# A = 2
# AA= 3
# [2, 3, 3, 2, 1]
# A = 3
# AA= 2
# [2, 3, 2, 2, 1]
# A = 2
# AA= 2
# [2, 3, 2, 2, 1]
# A = 1
# AA= 3
# [2, 3, 2, 2, 3]
