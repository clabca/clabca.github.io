# %% [markdown]
# # Modulo A : Funciones

# %% [markdown]
# ### ¿Qué es una función?
#
# Una función es código encapsulado que puede ser reutilizado
# fácilmente. Por lo general, recibe valores (parámetros) y retorna un
# valor.
#
# Ejemplos:
#
# >>> entero = int(4.5)
# >>> print(‘Hola’)

# %% [markdown]
# ### Definición de una función
#
# Las definición o “firma” de la función se compone de la palabra
# reservada def. Opcionalmente puede incluir parámetros y/o
# valor de retorno.
#
#       def nombre_función(parametro1, parametro2,...):
#
#         instrucciones de la función
#
#         return valor

# %% [markdown]
# ### Ejemplo de función
#
#
#     def perimetro(r):
#       resultado = 2 * 3.14 * r
#       return resultado
#
# ¿Cómo usamos esta función dentro de un programa?

# %% [markdown]
# ### Diferencia entre print y return
#
#
#     def perimetro(r):
#       resultado = 2 * 3.14 * r
#       print(resultado)
#
#     def perimetro(r):
#       resultado = 2 * 3.14 * r
#       return resultado

# %% [markdown]
# ### Uso de módulos
#
# Existen 2 maneras para importar objetos en Python
#
#     from math import cos, pi
#
#     from random import randint
#
#     print(cos(pi/2))
#
#     print(randint(0, 10))
#
# .
#
#
#     import math
#
#     print(math.cos(pi/2))
#     print(math.randint(0, 10))

# %% [markdown]
# ### Creación de módulos
#
#
# Ahora revisaremos dos archivos de código:
#
# • programa.py
#
# (archivo con el programa principal que usa las funciones de un módulo creado por nosotros).
#
#
# • circulos.py
#
# (módulo creado por nosotros con funciones).

# %% [markdown]
# ## Tipos de funciones

# %% [markdown]
# ### 1) Con un valor de retorno
#
#     def promedio(c1, c2, c3):
#       return round((c1+c2+c3) / 3)
#
# p = promedio(100, 50, 50)
#
# p
# 67

# %% [markdown]
# ### 2) Con múltiples valores de retorno
#
#     def convertir_horas_minutos(total_minutos):
#
#       horas = total_minutos // 60
#       minutos = total_minutos % 60
#       return horas, minutos
#
# >>> h, m = convertir_horas_minutos(89)

# %% [markdown]
# ### 3) Sin valor de retorno
#
#
# def imprimir_datos(nombre, apellido, edad, rut):
#
#
# print(‘Nombre:’, nombre, apellido)
#
# print(‘Rut:’, rut)
#
# print(‘Edad:’, edad)
#
#
# >>> imprimir_datos(‘Juan’,‘Perez’, 34, ‘11111111-1’)

# %% [markdown]
# ### 4) Parámetros con valores por omisión
#
#
#
#     def funcion(a, b=2, c=10):
#
#       return a + b + c
#
# >>> funcion(10)
#
# 22
#
# >>> funcion(10, 15)
#
# 35
#
# >>> funcion(10, 15, 20)
#
# 45

# %% [markdown]
# ## Ejercicio #1
#
# Escriba una función que determine si un número es par o no.

# %%
def es_par(numero):
  if numero%2 == 0:
    return print(True)
  else:
    return print(False)

es_par(3)
es_par(2)
es_par(7)
# Out:
# False
# True
# False

# %% [markdown]
# ## Ejercicio #2
#
# Escriba un programa que resuelva una ecuación de segundo grado de la forma:
#
#
# ![image.png](data:image/png;base64,...)
#
# Recuerde que primero debe calcular el discriminante (d=b**2–4*a*c)
# para determinar si la ecuación,
#
# (1) no tiene solución real (d<0),
#
#
# (2) tiene solución única (d==0) o
#
#
# (3) tiene 2 soluciones (d>0).

# %% [markdown]
# Forma  1 Ejercicio 2

# %%
def cuadratica(a,b,c):
  d=(b**2)-(4*a*c)
  if d<0:
    return print("No tiene Solucion Real")
  if d==0:
    x = (0-b)/(2*a)
    return print("Tiene Solucion Unica : X=",x)
  if d>0:
    x1 = (0-b+(d**0.5))/(2*a)
    x2 = (0-b-(d**0.5))/(2*a)
    return print("Tiene 2 Soluciones : X1=",x1,"   y  X2=",x2)

cuadratica(5,2,1)
# Out:
# No tiene Solucion Real

# %% [markdown]
# Forma  2 Ejercicio 2

# %%
def discriminante(a,b,c):
    resultado = b**2-4*a*c
    return resultado

p1 = float(input('Ingrese el valor a:'))
p2 = float(input('Ingrese el valor b:'))
p3 = float(input('Ingrese el valor c:'))

var_resultado = discriminante(p1,p2,p3)

if var_resultado < 0:
    print('La ecuacion no tiene solucion real')
elif var_resultado == 0:
    sol = -p2 / (2*p1)
    print('La solucion es unica y es sol=', sol)
else:
    sol = (-p2 - (var_resultado**0.5))/(2*p1)
    sol2 = (-p2 + (var_resultado**0.5))/(2*p1)
    print('Las soluciones son:')
    print('sol=', sol)
    print('sol2=', sol2)

# %%
cuadratica(5,6,1)
# Out:
# Tiene 2 Soluciones : X1= -0.2    y  X2= -1.0

# %% [markdown]
# ## Ejercicio #3
#
# Cree un módulo llamado “mimodulo.py” y agregue la función
# invertir_digitos(n) que reciba un número entero n, y entregue como resultado el número n, con los dígitos en orden inverso.
#
# Luego desarrolle un programa principal que use la función de dicho módulo.

# %%
def invertir_digitos(n):
    while n>0:
      d = n % 10
      n = n // 10
      print(d , end='')
      
invertir_digitos(56548)
# Out:
# 84565

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %run "/content/drive/My Drive/Colab Notebooks/mimodulo.py"

# %% [markdown]
# Modulo desde Google Drive

# %%
import mimodulo
n = int(input('Ingrese n: '))
print('El numero invertido es', mimodulo.invertir_digitos(n))
# Out:
# Ingrese n: 254125
# El numero invertido es 521452

# %% [markdown]
# ## Ejercicio #4
#
# Las funciones seno y coseno, pueden ser representadas por sumas infinitas:
#
# ![image.png](data:image/png;base64,...)
#
#
# 1) Escriba la función factorial_reciproco(n), que retorne el valor de 1/n!
#
# 2) Escriba la función signo(n) que retorne 1 cuando n es par, y -1 cuando n es impar.
#
# 3) Escriba las funciones seno_aprox(x, m) y coseno_aprox(x, m) que aproximen el seno y el coseno de x, usando los primeros m términos de las sumatorias.

# %%
def factorial_reciproco(n): 
	i = 1
	prod = 1
	while i <= n: 
		prod *= i
		i += 1
	return 1/prod

def signo(n): 
	return 1 if n % 2 == 0 else -1

def seno_aprox(x, m):
    i = 0
    suma = 0
    while i < m:
        suma += signo(i) * x ** (2 * i + 1) * factorial_reciproco(2 * i + 1)
        i += 1
    return suma

def coseno_aprox(x, m):
    i = 0
    suma = 0
    while i < m:
        suma += signo(i) * x ** (2 * i) * factorial_reciproco(2 * i)
        i += 1
    return suma

# %% [markdown]
# # Modulo B : Strings

# %% [markdown]
# ### Estructura de un string
#
# Los strings permiten representar texto en Python. Son un tipo de dato
# inmutable, esto es, no se puede modificar luego de su creación.
#
# >>> cadena = ‘’
#
# >>> cadena2 = ‘ ’
#
#
# >>> len(cadena)
#
# 0
# >>> len(cadena2)
#
# 1
#
# Se puede acceder a cada caracter mediante su posición
#
# ![image.png](data:image/png;base64,...)
#
#
#
# >>> cadena = ‘hola mundo’
#
# >>> cadena[0]
#
# h
#
#
# >>> cadena[5]
#
# m
#
#
# Se puede acceder a cada caracter mediante su posición negativa.
#
# ![image.png](data:image/png;base64,...)
#
#
# >>> cadena = ‘hola mundo’
#
# >>> cadena[-1]
#
# o
#
#
# >>> cadena[7]
#
# a

# %% [markdown]
# ### Substrings
#
# Además de acceder a cada carácter (elemento) por su posición, es posible obtener
# una porción del string (substring) mediante el operador :
#
# ![image.png](data:image/png;base64,...)
#
#
#
# >>> cadena = ‘hola mundo’
#
# >>> cadena[3:7]
#
# ‘a mu’
#
# >>> cadena[:7]
#
# ‘hola mu’
#
# >>> cadena[2:]
#
# ‘la mundo’
#
# >>> cadena[::2]
#
# ‘hl ud’

# %% [markdown]
# ### Recorrido de strings (con while)
#
# cadena = ‘hola mundo’
#
# i = 0
#
# while i < len(cadena):
#
# print(‘s=’, cadena[i])
#
# i += 1

# %% [markdown]
# ### Recorrido de strings (con for)
#
# cadena = ‘hola mundo’
#
# for c in cadena:
# print(‘s =’, c)

# %% [markdown]
# ### Reemplazar secciones de un string
#
# Método replace(a, s): reemplaza todas las apariciones del string a en
# el string s.
#
#
# >>> mensaje = ‘Estoy muy cansado’
#
# >>> print(mensaje.replace(‘cansado’, ‘animado’))
#
# >>> print(mensaje)
#
#
# >>> mensaje = mensaje.replace(‘cansado’, ‘animado’)
#
# >>> print(mensaje)
#
#
# >>> print(mensaje.replace(‘a’, ‘e’, 1))

# %% [markdown]
# ### Mayúsculas, minúsculas y posición
#
# Método upper(s): lleva a mayúsculas el string s
#
# >>> mensaje = ‘Estoy muy cansado’
#
# >>> mensaje.upper()
#
#
# Método lower(s): lleva a minúsculas el string s
#
#
# >>> mensaje = ‘BIENVENIDO A MI PROGRAMA’
#
# >>> mensaje.lower()
#
#
# Método index(caracter): entrega la posición del caracter
#
#
# >>> mensaje = ‘hola mundo’
#
# >>> mensaje.index(‘o’)

# %% [markdown]
# ### Interpolación de strings
#
# Método s.format(): permite generar un string dinámico a partir de un string
# “plantilla”.
#
# >>> s = ‘Soy {0} y vivo en {1}’
#
# >>> s.format(‘Juan’, ‘Santiago’)
# ‘Soy Juan y vivo en Santiago’
#
# >>> s.format(‘Erika’, ‘Berlin)
# ‘Soy Erika y vivo en Berlin’
#
# >>> ‘{0}{1}{0}’.format(‘hola’, ‘chao’)
# ‘holachaohola’

# %%
cadena ='hola'

# %%
cadena[0]
# Out:
# 'h'

# %%
cadena[2]
# Out:
# 'l'

# %%
cadena[-1]
# Out:
# 'a'

# %%
len(cadena)
# Out:
# 4

# %%
cadena='hola mundo'

# %%
cadena[3:7]
# Out:
# 'a mu'

# %%
cadena[:7]
# Out:
# 'hola mu'

# %%
cadena[2:]
# Out:
# 'la mundo'

# %%
cadena[::2] #2 salto
# Out:
# 'hl ud'

# %%
cadena[::1]
# Out:
# 'hola mundo'

# %%
i=0
while i<len(cadena):
  print(i, cadena[i])
  i +=1
# Out:
# 0 h
# 1 o
# 2 l
# 3 a
# 4
# 5 m
# 6 u
# 7 n
# 8 d
# 9 o

# %%
for c in cadena:
 print ('s =', c)
# Out:
# s = h
# s = o
# s = l
# s = a
# s =
# s = m
# s = u
# s = n
# s = d
# s = o

# %%
mensaje = 'Estoy muy cansado'

# %%
mensaje.replace('cansado','animado')
# Out:
# 'Estoy muy animado'

# %%
mensaje
# Out:
# 'Estoy muy animado'

# %%
mensaje = mensaje.replace('cansado','animado')

# %%
mensaje.index('u')
# Out:
# 7

# %%
'z' in mensaje
# Out:
# False

# %%
mensaje.upper()
# Out:
# 'ESTOY MUY ANIMADO'

# %%
mensaje.lower()
# Out:
# 'estoy muy animado'

# %%
s = 'Soy {0} y vivo en {1}'
s.format('Cristian', 'Santiago')
# Out:
# 'Soy Cristian y vivo en Santiago'

# %% [markdown]
# ### Ejercicio #1
#
# Una cadena de ADN es una secuencia de bases nitrogenadas llamadas: (1) adenina, (2) citosina, (3) timina y (4) guanina. En un programa una cadena se representa como un string de caracteres ‘a’, ‘c’, ‘t’ y ‘g’. Escriba la función cadena_al_azar(n) que retorne una cadena aleatoria de ADN de largo n.
#
# >>> cadena_al_azar(10)
#
# ‘acgtccgcct’
#
# >>> cadena_al_azar(10)
#
# ‘tgttcgcatt’
#
#
# Hint:
# >>> from random import choice
#
# >>> choice(‘atcg’)
#
# ‘t’
#
# >>> choice(‘atcg’)
#
# ‘g’

# %%
from random import choice
def cadena_al_azar(n):
  i=0
  var1='' 
  while n>i:
    i = i+1
    var1 = var1 + choice("atcg")
  return var1
print(cadena_al_azar(20))
# Out:
# ctcacgccaggaggcttaat

# %% [markdown]
# ### Ejercicio #2
#
# A cada cadena le corresponde una cadena complementaria, que se obtiene
# intercambiando las adeninas con las timinas, y las citosinas con las guaninas.
#
# cadena = ‘cagcccatgaggcagggtg’
#
# complemento = ‘gtcgggtactccgtcccac’
#
#
# Escriba la función complementaria(c) que entregue la cadena complementaria
# de c.
#
# >>> cadena = ‘cagcccatgaggcagggtg’
#
# >>> complementaria(cadena)
#
# ‘gtcgggtactccgtcccac’

# %%
#Forma 1
def complementaria_1(c): 
	nueva = ''
	for i in c: 
		if i == 'a': 
			nueva += 't'
		if i == 'c': 
			nueva += 'g'
		if i == 't': 
			nueva += 'a'
		if i == 'g': 
			nueva += 'c'
	return nueva
#Forma 2
def complementaria(c): 
	c = c.replace('a', 'T').replace('t', 'A').replace('c', 'G').replace('g', 'C').lower()
	return c

# %% [markdown]
# ### Ejercicio #3
#
# Cree una función codigo_palabra(codigo) que reciba un código cifrado de sólo
# letras y entregue el mensaje descifrado. La regla de descifrado es la siguiente: la palabra descifrada se obtiene recorriendo desde el final de la palabra hasta el comienzo, considerando las letras solo en ubicaciones impares. Empezando desde la última letra.
#
# >>> codigo_palabra(‘aczaarltp’)
#
# ‘plaza’
#
# >>> codigo_palabra(‘axruatgrrreov’)
#
# ‘vergara’

# %%
#version 1:
palabra = input('Ingrese palabra cifrada: ')
i = 1
nueva = ''
while i <= len(palabra):
    if i % 2 != 0:
        nueva += palabra[-i]
    i += 1
print(nueva)
# Out:
# Ingrese palabra cifrada: jijujiju
# uiui

# %%
#version 2:
palabra = input('Ingrese palabra cifrada: ')
i = 1
nueva = ''
while i <= len(palabra):
    nueva += palabra[-i]
    i += 2
print(nueva)
# Out:
# Ingrese palabra cifrada: lololeli
# ieoo

# %% [markdown]
# ### Ejercicio #4
#
# Cree una función codigo_hora(codigo) que reciba un código cifrado de
# sólo números y el caracter ‘:’ y entregue el código descrifrado. La regla de
# descifrado es la siguiente: sumar cada dígito anterior al caracter ‘:’ y
# calcular el resto de la división entera entre esa suma y 24. Luego, lo mismo
# con los dígitos después del carácter ‘:’, pero ahora el resto de la división es
# entre esa suma y 60.
#
# >>> codigo_hora(‘776199:68556’)
#
# ‘15:30’

# %%
codigo = input('Ingrese hora cifrada: ')
suma = 0
for c in codigo:
    if c != ':':
        suma += int(c)
    else:
        hora = suma % 24
        suma = 0
minutos = suma % 60
print('La hora descifrada es:', str(hora) + ':' + str(minutos))
# Out:
# Ingrese hora cifrada: 252456:1425
# La hora descifrada es: 0:12

# %% [markdown]
# ## Trabajo post-clase–Ejercicio #1
#
# Escriba un programa que lea una cantidad de palabras y calcule el largo de cada una, sin considerar las letras repetidas, determinando la más larga y más corta.
# Por ejemplo, la palabra “casa” es más corta que la palabra “reno”, ya que tiene 3 letras distintas (c, a y s). Mientras que “reno” tiene 4.
#
# Ingrese n: 3
#
# palabra 1: sabanas
#
# palabra 2: canales
#
# palabra 3: cojines
#
# La palabra mas larga es: cojines
#
# La palabra mas corta es: sabanas

# %%
def cuenta_letras(palabra):
  letras = len(set(palabra))
  return letras

cant = int(input('Ingrese Catidad de Palabras : ')) 
x=0
letpalcorta=99999
letpallarga=0
palcorta=''
pallarga=''
while x<cant:
  x=x+1
  palx = input('Ingrese Palabra ')
  if cuenta_letras(palx) < letpalcorta:
    palcorta = palx
    letpalcorta = cuenta_letras(palx)
  if cuenta_letras(palx) > letpallarga:
    pallarga = palx
    letpallarga = cuenta_letras(palx)


print('Larga '+pallarga)  
print('Corta '+palcorta)
# Out:
# Ingrese Catidad de Palabras : 3
# Ingrese Palabra sabanas
# Ingrese Palabra canales
# Ingrese Palabra cojines
# Larga cojines
# Corta sabanas

# %% [markdown]
# ## Trabajo post-clase–Ejercicio #2A
#
# Escriba la función valida(cadena) que reciba un string con una cadena de ADN y retorne True si la cadena es válida o False si no lo es.
# Una cadena no es válida cuando aparecen bases nitrogenadas distintas a las indicadas previamente (Adenina,Citosina,Guanina y Timina)
#
#
# >>> valida(‘CTGA CTGAAATT GGGC CTGG CCCC’)
#  True
#
# >>> valida(‘CTGA XCGA CGAT GGTA ACCC CCPC TTAA’)
#  False

# %%
def valida(cadena):
  for x in cadena:
    if (x not in 'ACGT') and (x !=' '):
      return False
  return True

# %%
valida('CTGA CTGAAATT GGGC CTGG CCCC')
# Out:
# True

# %%
valida('CTGA XCGA CGAT GGTA ACCC CCPC TTAA')
# Out:
# False

# %% [markdown]
# ## Trabajo post-clase–Ejercicio #2B
#
# Escriba la función cantidad(cadena,base) que reciba un string con una cadena de ADN y una base nitrogenada.
#
# La función debe retornar la cantidad de apariciones de la base en la cadena.
#
#
# >>> cantidad(‘CTGA CTGAAATT GGGC CTGG CCCC’, ‘A’)
#  4

# %%
def cantidad(cadena,base):
  cant = 0
  for x in cadena:
    if x == base:
      cant = cant + 1
  return cant

# %%
cantidad('CTGA CTGAAATT GGGC CTGG CCCC', 'A')
# Out:
# 4

# %% [markdown]
# ## Trabajo post-clase–Ejercicio #2C
#
# Los científicos encontraron un patrón de clasificación, que se deduce de la cantidad mayoritaria de cierto grupo de bases.
#
# Si la suma de las cantidades de Citosina y Guanina es mayor a la de Adenina y Timina, es una especie vegetal, en caso contrario es una especie animal.
#
#
# Escriba un programa que pregunte la cantidad de cadenas de ADN a evaluar, luego solicite las cadenas y finalmente muestre las cantidades de cada especie y cadenas no válidas.
#  Use las funciones anteriores.
#
#
#
# Cantidad de cadenas a ingresar: 3
#
# Ingrese cadena 1: CGTA CAGT TTGG GGTA AATG CATG
#
# Ingrese cadena 2: CACC CTGA GGAA ACAA XTFC ATGG
#
# Ingrese cadena 3: TGTG TTGA ATGA CTAT ATTT
#
# Cantidad animales: 2
#
# Cantidad vegetales: 0
#
# Cantidad no validas: 1

# %%
cantcadenas = int(input('Ingrese Cantidad de cadenas a evaluar '))
x=0
novalidas=0
vegetal=0
animal=0
while x<cantcadenas:
  x=x+1
  cadenax = input('ingrese Cadena ' + str(x))
  if valida(cadenax)==False:
    novalidas=+1
  else:
    if cantidad(cadenax,'CG')>cantidad(cadenax,'AT'):
      vegetal +=1
    else:
      animal +=1

print('Animales :',animal)
print('Vegetales :',vegetal)
print('No validas :',novalidas)
# Out:
# Ingrese Cantidad de cadenas a evaluar 3
# ingrese Cadena 1CGTA CAGT TTGG GGTA AATG CATG
# ingrese Cadena 2CACC CTGA GGAA ACAA XTFC ATGG
# ingrese Cadena 3TGTG TTGA ATGA CTAT ATTT
# Animales : 2
# Vegetales : 0
# No validas : 1
