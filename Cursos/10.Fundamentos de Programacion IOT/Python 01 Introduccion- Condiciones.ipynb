# %% [markdown]
# # Bloque A Introduccion y Condiciones

# %% [markdown]
# ### ¿Qué es Python?
#
# • Lenguaje de programación “multipropósito”
#
# • Interpretado (no compilado)
#
# • Python puede ser interpretado desde:
#
# ✓ La consola de Python (o Python Shell)
#
# ✓ Archivos de texto con extensión .py en un editor de código
#
# • Instalar la versión de Python 3.8.X (no soportada por Windows XP y previos)

# %% [markdown]
# ### Entorno de Desarrollo Integrado (IDE)
#
# • Un IDE facilita la escritura de código al incluir asistencias al momento del desarrollo:
#
# o Autocompletar
#
# o Python shell en el mismo lugar
#
# o Listado de archivos del proyecto
#
# o Ejecución y Depuración de código
#
# • El que usaremos (recomendado) en el módulo es PyCharm Community Edition
#
# (https://www.jetbrains.com/es-es/pycharm/download/) 14

# %% [markdown]
# ### IDE online: repl.it
#
# • También disponemos de una opción muy popular y online:
#
# https://replit.com/
#
# • Permite codificar de forma colaborativa, con otros compañeros.
#
# • Vamos a probarlo!

# %% [markdown]
# ### Tipos de datos
#
# Números enteros (int)
#
# >>> 1
#
# >>> +133
#
# >>> -392
#
#
# Números reales (float)
#
# >>> -0.22
#
# >>> .1
#
# >>> 3.22e34
#
#
# Valores lógicos (bool)
#
# >>> True
#
# >>> False
#
#
#
# Texto (str)
#
# >>> “Hola”
#
# >>> ‘Hola’
#
# >>> “Bernardo O’Higgins”
#
# >>> ‘Le decían “usted”‘

# %% [markdown]
# ### Expresiones y operadores
#
# • Expresión: combinación de valores y operadores que al ser evaluados entregan
#
# un resultado.
#
# • Operador: símbolo en una expresión que representa una operación aplicada a los
# valores.

# %% [markdown]
# ### Operadores aritméticos
#
# - Suma (+)
# - Resta (-)
# - Multiplicación (*)
# - División (/)
# - División entera (//)
# - Módulo (%)
# - Potencia (**)

# %% [markdown]
# ### Ejemplos de expresiones
#
# >>> 2 * 3 + 4
#
# 10
#
# >>> ‘hola’ + ‘ mundo’
#
# ‘hola mundo’
#
# >>> x = 3.5
#
# >>> 5 + x ** 2
#
# 17.25
#
# >>> abs(x – 10)
#
# 6.5

# %% [markdown]
# ### Operadores aritméticos
#
# >>> 832 + 123
#
# 955
#
# >>> 1.22 * 6
#
# 7.32
#
# >> 15 / 4
#
# 3.75
#
# >> 15 // 4
#
# 3
#
# >> 1.2 ** 2
#
# 1.44
#
# >> 15 % 4
#
# 3

# %%
832 + 123
# Out:
# 955

# %%
1.22 * 6
# Out:
# 7.32

# %%
15 / 4
# Out:
# 3.75

# %%
15 // 4
# Out:
# 3

# %%
1.2 ** 2
# Out:
# 1.44

# %%
15 % 4
# Out:
# 3

# %% [markdown]
# ### Operadores lógicos
#
# >>> not False
#
# True
#
# >>> (True or (not True)) and (not False)
#
# True
#
# >>> ((3 + 4) < 1) and ((2 * 3) ** 2 >= 5)
#
# False
#
# >>> ((3 + 4) < 1) or ((2 * 3) ** 2 >= 5)
#
# True

# %% [markdown]
# ### Operadores de texto
#
#
# >>> ‘bienve’ + ‘nido’
#
# ‘bienvenido’
#
# >>> “tagua” * 2
#
# ‘taguatagua’
#
# >>> ‘ama’ in ‘amarillo’
#
# True
#
# >>> ‘amara’ in ‘amarillo’
#
# False
#
# >>> len(‘amarillo’)
#
# 8

# %% [markdown]
# ### Llamado a funciones y uso de bibliotecas
#
# >>> abs(62-500)
#
# 438
#
# >>> round(79.5)
#
# 80
#
# >>> from math import exp
#
# >>> exp(2)
#
# 7.38905609893065
#
# >>> from random import randint
#
# >>> randint(1, 20)
#
# 4

# %% [markdown]
# ### Precedencia de operadores
#
# • Las expresiones se evalúan siguiendo las siguientes reglas, de menor a
# mayor:
#
# 1. +, -
#
# 2. *, /, //, %
#
# 3. +x, -x, (unario)
#
# 4. **
#
# 5. abs(), randint() (llamada a funciones)
#
# 6. (, ) (paréntesis)

# %% [markdown]
# ### Conversión entre tipos de datos
#
# • >>> int(3.5)
#
# 3
#
# • >>> float(“39”)
#
# 39.0
#
# • >>> str(25)
#
# “25”
#
# • >>> bool(0.0)
#
# False

# %% [markdown]
# ### Asignación de variables
#
#
# La asignación de variables es de la siguiente forma:
#
#     <variable> = <expresión>
#
#
# 1. Se evalúa la expresión
#
# 2. Se asigna el resultado de la evaluación, a la variable
#
#
# Asignación de variables
#
#
# ¿Con qué valor quedan las siguientes variables?
#
# >>> a = 4 + 6
#
# >>> b = a + 4
#
# >>> a = 2
#
# >>> d = a - 3
#
# >>> e = e + 1

# %% [markdown]
# ### Entrada de datos
#
# nombre = input(“Ingrese su nombre: ”)
#
# edad = int(input(“Ingrese su edad: “))
#
# estatura = float(input(“Ingrese su estatura”)

# %%
nombre = input("Ingrese su nombre: ")

edad = int(input('Ingrese su edad: '))

estatura = float(input("Ingrese su estatura: "))
# Out:
# Ingrese su nombre: Cristian
# Ingrese su edad: 32
# Ingrese su estatura: 1.83

# %% [markdown]
# ### Salida de datos
#
# print(“hola mundo”)
#
# a = 10
#
# x = a ** 2
#
# print(a, ‘al cuadrado es’, x)
#
#
# print(a, x)
#
# print(a)
#
# print(x)

# %%
print("hola mundo")

a = 10
x = a ** 2
print(a, "al cuadrado es", x)

print(a, x)

print(a)
print(x)
# Out:
# hola mundo
# 10 al cuadrado es 100
# 10 100
# 10
# 100

# %% [markdown]
# ### Comentarios en el código
#
#  #A continuacion se muestra la suma de 2+2
#
# print(2 + 2)

# %%
#A continuacion se muestra la suma de 2+2
print(2 + 2)
# Out:
# 4

# %% [markdown]
# ### Ejercicio 1
#
# Escriba un programa que pida su nombre y lo salude.
#
# Caso de prueba:
#
# >>> Ingrese su nombre: Pedro
#
# Hola Pedro, bienvenido al modulo

# %%
nombre = input('Nombre: ')
print('Hola', nombre + ',bienvenido al modulo 2')
# Out:
# Nombre: Cristian Labra Castro
# Hola Cristian Labra Castro,bienvenido al modulo 2

# %% [markdown]
# ### Ejercicio 2
#
# Escriba un programa que determine el área de un círculo a partir de su radio.
#
# Caso de prueba:
#
# >>> Ingrese el radio de un círculo: 10
#
# El área de la circunferencia es 314.16

# %%
from math import pi

r = float(input('Ingrese el radio de un circulo: '))
area = pi * r ** 2
print('El area de la circunferencia es', round(area, 2))
# Out:
# Ingrese el radio de un circulo: 10
# El area de la circunferencia es 314.16

# %% [markdown]
# ### Ejercicio 3
#
# Escriba un programa que invierta un número entero de tres dígitos.
#
# Caso de prueba:
#
# >>> Ingrese un número: 231
# El numero invertido es 132

# %%
numero = int(input('Ingrese numero: '))
d1 = numero % 10
numero = numero // 10
d2 = numero % 10
numero = numero // 10
d3 = numero % 10
#invertido = str(d1) + str(d2) + str(d3)
invertido = d1 * 100 + d2 * 10 + d3
print('El numero invertido es', invertido)
# Out:
# Ingrese numero: 159
# El numero invertido es 951

# %% [markdown]
# ### Ejercicio 4
#
# Escriba un programa que convierta de centímetros a pulgadas. Una pulgada
# es igual a 2.54 centímetros.
#
# Casos de prueba:
#
# >>> Ingrese longitud: 45
# 45.0 cm = 17.7165 in
#
# >>> Ingrese longitud: 13
# 13.0 cm = 5.1181 in

# %%
lng = float(input('Ingrese longitud: '))
pulgadas = round(lng / 2.54, 4)
print(lng, 'cm =', pulgadas, 'in')
# Out:
# Ingrese longitud: 100
# 100.0 cm = 39.3701 in

# %% [markdown]
# ### Ejercicio 5
#
# Escriba un programa que transforme una temperatura ingresada por usuario
# de grados Farenheit (F) a Celsius (C), usando al siguiente fórmula:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Caso de prueba:
#
# Temp. En Farenheit: 67
# Los 67.0 F en grados Celsius son 19 C

# %%
f = float(input('Temp. En Fahrenheit: '))
c = (f - 32) * 5 / 9
print('Los', f, 'F en grados Celsius son', round(c), 'C')
# Out:
# Temp. En Fahrenheit: 102
# Los 102.0 F en grados Celsius son 39 C

# %% [markdown]
# ### Ejercicio 6
#
# Escriba un programa que calcule el área de un triángulo a partir de la
# longitud de sus lados (a, b y c), y de su semiperímetro (s) mediante la
# siguiente fórmula:
#
#
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt

l1 = float(input("Ingrese longitud de lado 1: "))
l2 = float(input("Ingrese longitud de lado 2: "))
l3 = float(input("Ingrese longitud de lado 3: "))
s = (l1+l2+l3)/2 #semiperímetro

d1 = s-l1 #diferencia1
d2 = s-l2 #diferencia2
d3 = s-l3 #diferencia3
prod = s*d1*d2*d3 #producto de diferencias y semiperimetro
area= sqrt(prod) #raiz cuadrada

print("El área del triángulo es", area)
# Out:
# Ingrese longitud de lado 1: 4
# Ingrese longitud de lado 2: 5
# Ingrese longitud de lado 3: 6
# El área del triángulo es 9.921567416492215

# %% [markdown]
# # Bloque B Condiciones

# %% [markdown]
# ### Operadores relacionales
#
# Comparan valores teniendo siempre como resultado un valor lógico.
#
# • Igual a (==)
#
# • Distinto (!=)
#
# • Mayor que (>)
#
# • Menor que (<)
#
# • Mayor o igual que (>=)
#
# • Menor o igual que (<=)

# %% [markdown]
# ### Operadores lógicos
#
# Tienen operandos y el tipo de resultado es un valor lógico.
#
# • Conjunción lógica: and
#
# • Disyunción lógica: or
#
# • Negación Lógica: not

# %% [markdown]
# ### Sentencias condicionales: if
#
# La sentencia if ejecuta las instrucciones sólo si la condición se hace verdadera. En caso de que la condición sea falsa, no se ejecutan.
#
#
# Sintaxis:
#
#
# if condición:
#
# ___instrucciones
#
#
#
# ***Atención con la “sangría ___”.***
#
# A esto llamamos: indentación
#
# Así le indicamos a Python que dichas
# instrucciones están dentro de la
# estructura if.

# %% [markdown]
# ### Ejemplo:
#
# Escriba un programa que pida al usuario tres notas, y lo felicite si su promedio
# es mayor a 80.
#
# Nota 1: 80
#
# Nota 2: 33
#
# Nota 3: 20
#
# Su promedio es 44
#
#
# Nota 1: 100
#
# Nota 2: 100
#
# Nota 3: 80
#
# Su promedio es 93
#
# Felicitaciones!

# %%
#Ejemplo de if

nota1 = int(input('Nota 1: '))
nota2 = int(input('Nota 2: '))
nota3 = int(input('Nota 3: '))
promedio = round((nota1 + nota2 + nota3) / 3)
print('Su promedio es', promedio)
if promedio >= 80:
    print("Felicitaciones!")
# Out:
# Nota 1: 100
# Nota 2: 100
# Nota 3: 80
# Su promedio es 93
# Felicitaciones!

# %% [markdown]
# ### Sentencias condicionales: if-else
#
# La sentencia if-else ejecuta cierto grupo de instrucciones dependiendo de si la condición es verdadera o falsa.
#
# Sintaxis:
#
# if condición:
#
#       instrucciones en caso verdadero
#
# else:
#
#       instrucciones en caso falso

# %% [markdown]
# ### Ejemplo:
#
# Escriba un programa que pida al usuario ingresar tres notas, e indique si aprobó o no. Considere que la escala es de 0 a 100, y se aprueba desde 55.
#
# Nota 1: 79
#
# Nota 2: 40
#
# Nota 3: 10
#
# Usted reprobo con 43
#
# Nota 1: 99
#
# Nota 2: 100
#
# Nota 3: 56
#
# Usted aprobo con 85

# %%
# Ejemplo de if-else
nota1 = int(input('Nota 1: '))
nota2 = int(input('Nota 2: '))
nota3 = int(input('Nota 3: '))
promedio = round((nota1 + nota2 + nota3) / 3)
if promedio >= 55:
    print("Usted aprobo con", promedio)
else:
    print("Usted reprobo con", promedio)
# Out:
# Nota 1: 99
# Nota 2: 100
# Nota 3: 56
# Usted aprobo con 85

# %% [markdown]
# ### Sentencias condicionales: if-elif-else
#
# La sentencia if-elif-else depende de dos o más condiciones. La primera que sea verdadera determinará qué instrucciones se ejecutarán.
#
# Sintaxis:
#
# if condición1:
#
#       instrucciones si condición 1 es verdadera
#
# elif condición2:
#
#       instrucciones si condición 2 es verdadera
#
# elif condición3:
#
#       instrucciones si condición 3 es verdadera

# %% [markdown]
# ### Ejemplo:
#
# Escriba un programa que pida al usuario tres notas, e indique si su promedio es pésimo (< 30), mediocre (30 a 54), aceptable (55 a 79) o excelente (>= 80).
#
# Nota 1: 32
#
# Nota 2: 90
#
# Nota 3: 99
#
# Su promedio 74 es aceptable
#
#
# Nota 1: 80
#
# Nota 2: 100
#
# Nota 3: 91
#
# Su promedio 90 es excelente!

# %%
# Ejemplo de if - elif - else
nota1 = int(input('Nota 1: '))
nota2 = int(input('Nota 2: '))
nota3 = int(input('Nota 3: '))
promedio = round((nota1 + nota2 + nota3) / 3)
if promedio >= 80:
    print("Su promedio es excelente")
elif promedio >= 55:
    print("Su promedio es aceptable.")
elif promedio >= 30:
    print("Su promedio es mediocre")
else:
    print("Su promedio es pesimo")
# Out:
# Nota 1: 80
# Nota 2: 100
# Nota 3: 99
# Su promedio es excelente

# %% [markdown]
# ### Ejercicio 1
# Escriba un programa que genere aleatoriamente el lanzamiento de una moneda y muestre por pantalla su resultado (CARA o SELLO).

# %%
from random import randint

moneda = randint(0, 1)

if moneda == 0:
    print("El lanzamiento es CARA.")
else:
    print("El lanzamiento es SELLO.")
# Out:
# El lanzamiento es SELLO.

# %% [markdown]
# ### Ejercicio 2
#
# Escriba un programa que pida al usuario dos palabras, e indique cual de ellas es la más larga, y por cuantas letras lo es.
#
# Ingrese palabra 1: paralelepipedo
#
# Ingrese palabra 2: paralele
#
# Palabra 1 es mayor a palabra 2
#
#
# Ingrese palabra 1: bienvenido
#
# Ingrese palabra 2: bienvenida
#
# Ambas palabras tienen el mismo largo

# %%
palabra1 = input('Ingrese palabra 1: ')
palabra2 = input('Ingrese palabra 2: ')
largo1 = len(palabra1)
largo2 = len(palabra2)
if largo1 == largo2:
    print('Ambas palabras tienen el mismo largo')
elif largo2 > largo1:
    print('Palabra 2 es mayor que la palabra 1 en', largo2 - largo1)
else:
    print('Palabra 1 es mayor que la palabra 2 en', largo1 - largo2)
# Out:
# Ingrese palabra 1: para
# Ingrese palabra 2: paralelepidedo
# Palabra 2 es mayor que la palabra 1 en 10

# %% [markdown]
# ### Ejercicio 3
#
# Escriba un programa que reciba como entrada la estatura, el peso y la edad de una persona, y el entregue la condición de riesgo.
#
# Considere que el IMC se calcula como: peso / estatura ** 2
#
# ![image.png](data:image/png;base64,...)

# %%
estatura = float(input('Ingrese estatura: '))
peso = float(input('Ingrese peso: '))
edad = int(input('Ingrese edad: '))

imc = peso / (estatura ** 2)

if edad < 45:
    if imc < 22.0:
        print('Bajo')
    else:
        print('Medio')
else:
    if imc < 22.0:
        print('Medio')
    else:
        print('Alto')
# Out:
# Ingrese estatura: 1.45
# Ingrese peso: 88
# Ingrese edad: 55
# Alto

# %% [markdown]
# ### Ejercicio 4
#
# Escriba un programa que considere la siguiente tabla para mostrar el total de impuestos a pagar por una persona según su sueldo.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Ingrese su sueldo: 1000000
# Usted pagara 12000 de impuesto
#
# Ingrese su sueldo: 999
# Usted pagara 0 de impuesto

# %%
sueldo = int(input('Ingrese su sueldo: '))
if sueldo < 1000:
    tasa = 0
elif sueldo < 2000:
    tasa = 0.05
elif sueldo < 4000:
    tasa = 0.1
else:
    tasa = 0.12
print('Usted pagara', round(tasa * sueldo), 'de impuesto')
# Out:
# Ingrese su sueldo: 3000
# Usted pagara 300 de impuesto

# %% [markdown]
# ### Ejercicio 5
#
# Escriba un programa que permita ingresar 5 números enteros y
# determine cuál de los cuatro números es el más lejano al primero.
#
# Primer numero: 2
#
# Ingrese numero: 4
#
# Ingrese numero: 6
#
# Ingrese numero: 10
#
# Ingrese numero: 1
#
# El numero mas lejano al primero es el 10

# %%
numero1 = int(input('Primer numero: '))
numero2 = int(input('Ingrese numero: '))
numero3 = int(input('Ingrese numero: '))
numero4 = int(input('Ingrese numero: '))
numero5 = int(input('Ingrese numero: '))

dif2 = abs(numero2 - numero1)
dif3 = abs(numero3 - numero1)
dif4 = abs(numero4 - numero1)
dif5 = abs(numero5 - numero1)

if dif2 > dif3 and dif2 > dif4 and dif2 > dif5:
    print('El numero mas lejano al primero es el', numero2)
if dif3 > dif2 and dif3 > dif4 and dif3 > dif5:
    print('El numero mas lejano al primero es el', numero3)
if dif4 > dif2 and dif4 > dif3 and dif4 > dif5:
    print('El numero mas lejano al primero es el', numero4)
if dif5 > dif2 and dif5 > dif3 and dif5 > dif4:
    print('El numero mas lejano al primero es el', numero5)
# Out:
# Primer numero: 10
# Ingrese numero: 20
# Ingrese numero: 30
# Ingrese numero: 40
# Ingrese numero: 50
# El numero mas lejano al primero es el 50
