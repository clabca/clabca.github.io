# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/My Drive/Colab Notebooks/supermercado_c4.py"

# %% [markdown]
# # Modulo A :Listas  [ , ]

# %%
productos
# Out:
# [(41419, 'Fideos', 450, 210),
#  (70717, 'Cuaderno', 900, 119),
#  (78714, 'Jabon', 730, 708),
#  (30877, 'Desodorante', 2190, 79),
#  (47470, 'Yogur', 99, 832),
#  (50809, 'Palta', 500, 55),
#  (75466, 'Galletas', 235, 0),
#  (33692, 'Bebida', 700, 20),
#  (89148, 'Arroz', 900, 121),
#  (66194, 'Lapiz', 120, 900),
#  (15982, 'Vuvuzela', 12990, 40),
#  (41235, 'Chocolate', 3099, 48)]

# %%
clientes
# Out:
# [('11652624-7', 'Juan Perez'),
#  ('8830268-0', 'Sebastian Casanueva'),
#  ('7547896-8', 'Victor Gamonal')]

# %%
ventas
# Out:
# [(1, (2010, 9, 12), '8830268-0'),
#  (2, (2010, 9, 19), '11652624-7'),
#  (3, (2010, 9, 30), '7547896-8'),
#  (4, (2010, 10, 1), '8830268-0'),
#  (5, (2010, 10, 13), '7547896-8'),
#  (6, (2010, 11, 11), '11652624-7')]

# %%
itemes
# Out:
# [(1, 89148, 3),
#  (2, 50809, 4),
#  (2, 33692, 2),
#  (2, 47470, 6),
#  (3, 30877, 1),
#  (4, 89148, 1),
#  (4, 75466, 2),
#  (5, 89148, 2),
#  (5, 47470, 10),
#  (6, 41419, 2)]

# %% [markdown]
# ### Crear listas
#
# >>> lista1 = []
#
# >>> lista2 = list()
#
# >>> lista3 = [1, 2, 3, 4]
#
# >>> lista4 = [[1,2], [3,4], [5,6]]
#
# >>> lista5 = [‘hola’, [1,2], 1]

# %% [markdown]
# ### Agregar cosas a una lista
#
# >>> valores = []
# >>> valores.append(5)
#
# >>> valores.append(10)
#
# >>> valores.append(6)
#
# >>> valores
# [5, 10, 6]
#
# >>> valores.append(-3)
# [5, 10, 6, -3]

# %%
valores = []
valores.append(4)
valores.append(1)
valores.append(1)
valores.append(-1)

# %%
valores
# Out:
# [4, 1, 1, -1]

# %% [markdown]
# ### Agregar valores a una lista usando range()
#
# >>> valores = list(range(5))
# >>> valores
# [0, 1, 2, 3, 4]
#
# >>> list(range(3, 8))
# [3, 4, 5, 6, 7]
#
# >>> list(range(5, 1))
# []
#
# >>> list(range(5, 1, -1))
# [5, 4, 3, 2]

# %%
list(range(7))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list(range(3,8))
# Out:
# [3, 4, 5, 6, 7]

# %%
list(range(3,8,2))
# Out:
# [3, 5, 7]

# %%
list(range(20,9,-1))
# Out:
# [20, 19, 18, 17, 16, 15, 14, 13, 12, 11, 10]

# %% [markdown]
# ### Acceder a elementos de una lista
#
# >>> nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# >>> nombres[0]
#
# ‘Juan’
#
# >>> nombres[-1]
#
# ‘Martin’
#
# >>> nombres.index(‘Pedro’)
#
# 1
#
# >>> len(nombres)

# %% [markdown]
# ### Modificar elementos de una lista (mutable)
#
# >>> nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# >>> nombres[0] = ‘Juanito’
#
# >>> nombres
# [‘Juanito’, ‘Pedro’, ‘Ana’, ‘Martin’]

# %% [markdown]
# ### 1. Concatenación de listas (+)
#
# >>> a = [1, 2, 3, 4]
#
# >>> b = [5, 6, 7, 8]
#
# >>> c = a + b
#
# >>> d = b + a
#
#
# >>> c
#
# [1, 2, 3, 4, 5, 6, 7, 8]
#
# >>> d
#
# [5, 6, 7, 8, 1, 2, 3, 4]

# %% [markdown]
# ### 2. Repetición de listas (*)
#
# >>> a = [1,4,6]
#
# >>> b = a * 3
#
# b
#
# [1, 4, 6, 1, 4, 6, 1, 4, 6]

# %% [markdown]
# ### 3. Verificar si un elemento está en la lista
#
# a = [1,2,3,4]
#
# >>> 10 not in a
#
# True
#
# >>> 6 in a
#
# False

# %% [markdown]
# ### 4. Eliminación de elementos de una lista
#
# >>> nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
#
# Por posición:
#
#
# >>> del nombres[2]
#
# >>> nombres
#
# [‘Juanito’, ‘Pedro’, ‘Martin’]

# %% [markdown]
# ### Funciones sobre listas
#
#
# >>> edades = [10, 3, 18, 22]
#
# >>> len(edades)
#
# 4
# >>> sum(edades)
#
# 53
# >>> min(edades)
#
# 3
# >>> max(edades)
#
# 22

# %% [markdown]
# ### Métodos de listas
#
# l = lista
# • Agregar un elemento x: l.append(x)
#
# • Agregar un elemento x en posición i: l.insert(i, x)
#
# i= posicion
#
# x= que se inserta
#
# • Contar aparición de un elemento x: l.count(x)
#
# • Obtener el índice de un elemento x: l.index(x)
#
# • Eliminar un elemento x: l.remove(x)
#
# • Invertir una lista: l.reverse()
#
# • Ordenar una lista: l.sort()
# ordena de menor a mayor

# %% [markdown]
# ### Recorrido de listas usando while
#
# nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# i = 0
#
# while i < len(nombres):
#
# print(nombres[i])
#
# i += 1
#
# Recorrido de listas en paralelo:
#
#
# nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# edades = [10, 3, 18, 22]
#
# i = 0
#
# while i < len(nombres):
#
#
# print(nombres[i], ‘tiene’, edades[i], ‘anios’)
#
# i += 1

# %%
nombres = ['Juan', 'Pedro', 'Ana', 'Martin']
edades = [10, 3, 18, 22]
i = 0

while i < len(nombres):
  print(nombres[i], 'tiene', edades[i], 'anios')
  i += 1
# Out:
# Juan tiene 10 anios
# Pedro tiene 3 anios
# Ana tiene 18 anios
# Martin tiene 22 anios

# %% [markdown]
# ### Recorrido de listas usando for
#
#
# nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# for nombre in nombres:
#
# print(nombre)
#
#
# Recorrido de listas en paralelo:
#
#
# nombres = [‘Juan’, ‘Pedro’, ‘Ana’, ‘Martin’]
#
# edades = [10, 3, 18, 22]
#
# for i in range(len(nombres)):
#   print(nombres[i], ‘tiene’, edades[i], ‘anios’)

# %%
for i in range(len(nombres)):
  print(nombres[i], 'tiene', edades[i], 'anios')
# Out:
# Juan tiene 10 anios
# Pedro tiene 3 anios
# Ana tiene 18 anios
# Martin tiene 22 anios

# %% [markdown]
# ### Operador slice [:]
#
#
# >>> lista = [1, 3, 5, 7, 9, 11, 13]
#
#
# >>> lista[3:5]
#
# [7, 9]
#
# >> lista[3:]
#
# [7, 9, 11, 13]
#
# >>> lista[:3]
#
# [1, 3, 5]
#
# >>> lista[::-1]
#
# [13, 11, 9, 7, 5, 3, 1]

# %% [markdown]
# ### Trabajo grupal – Ejercicio #1
#
# Desarrolle una función llamada desviacion_estandar(valores) cuyo parámetro
# valores sea una lista de números reales. La función debe retornar la desviación estándar
# de los valores:
#
# Donde n es la cantidad de valores, xҧes el promedio, y los xi son cada uno de los
# valores. Esto significa que hay que hacerlo siguiendo los siguientes pasos:
#
# 1. Calcular el promedio de los valores
# 2. A cada valor, restarle el promedio, y el resultado elevarlo al cuadrado
# 3. Sumar todos los valores obtenidos
# 4. Dividir la suma por la cantidad de valores y sacar la raíz cuadrada del resultado.
#
# Trabajo grupal – Ejercicio #1 (casos de prueba)
#
# >>> desviacion_estandar([1.3, 1.3, 1.3]
# 0.0
#
# >>> desviacion_estandar([4.0, 1.0, 11.0, 13.0, 2.0, 7.0])
# 4.88535225615
#
# >>> desviacion_estandar([1.5, 9.5])
# 5.65685424949

# %%
def desviacion_estandar(valores):
  promedio = sum(valores)/len(valores)
  resultado =0

  for valor in valores:
    resultado+=(valor-promedio)**2
  return (resultado/(len(valores)-1))**0.5

# %%
desviacion_estandar([1.5,9.5])
# Out:
# 5.656854249492381

# %% [markdown]
# ### Trabajo grupal – Ejercicio #2
#
# El producto interno de dos listas de números es la suma de los productos de
# los términos de ambas. Por ejemplo, si: a = [5, 1, 6] y b = [1, -2, 8]
#
# entonces el producto interno entre a y b es: (5 * 1) + (1 * -2) + (6 * 8)
#
#
# Escriba la función producto_interno(a, b) que entregue el producto interno
# entre a y b.
#
#
# >>> a = [7, 1, 4, 9, 8]
# >>> b = range(5)
# >>> producto_interno(a, b)
# 68

# %%
def producto_interno(a,b):
  p=0
  x=0
  while x<len(a):
    p += a[x]*b[x]
    x+=1
  return p

# %%
a=[5,1,6]

# %%
b=[1,-2,8]

# %%
producto_interno(a,b)
# Out:
# 51

# %% [markdown]
# ### Trabajo grupal – Ejercicio #3
#
# Dos listas de números son ortogonales si su producto interno es cero. Escriba
# la función son_ortogonales(a, b) que indique si a y b son ortogonales.
#
# >>> son_ortogonales([2, 1], [-3, 6])
# True

# %%
def son_ortogonales(a,b):
  return producto_interno(a,b)==0

# %%
son_ortogonales([2, 1], [-3, 6])
# Out:
# True

# %% [markdown]
# # Modulo B : Tuplas  ( , )

# %% [markdown]
# ### Tuplas
# •
# Estructuras de Python que permiten almacenar una colección de valores.
#
# •
# Se diferencian de las listas, principalmente porque son inmutables(no cambian luego de su creación).
#
# •
# Recomendadas para agrupar valores que por su naturaleza, deben ir juntos.

# %% [markdown]
# ### Creación de tuplas
#
# >>> t1 = tuple()
#
# >>> t2 = ()
#
# >>> t3 = (1, 2, 3)
#
# >>> t4 = (1, (1,2), True, ‘hola’)

# %% [markdown]
# ### Desempaquetado de tuplas
# >>> tupla = (‘Subaru’, ‘Forester’, 2020)
#
# >>> marca, modelo, anio= tupla
#
# >>> print(modelo)
#
# Forester
#
# persona = (‘Arturo’, ‘Prat’, 1848)
#
# >>> print(tupla[2])

# %% [markdown]
# ### Comparación de tuplas
# Dos tuplas son iguales cuando tienen el mismo largo y los elementos son idénticos.
#
# >>> (3, 3, 0) == (3, 3)
#
# False
#
# >>> (1, 2, 3) == (1, 2, 0)
#
# False
#
# >>> (1, 2, 3) == (1, 2, 3)
#
# True
#
# Para saber si una tupla es mayor o no a otra, se comparan los elementos en la primera posición que sean distintos.
#
# >>> (1, 4, 5, 0) < (1, 4, 7)
#
# True
#
# >>> (1, 2) < (1, 2, 4)
#
# True

# %% [markdown]
# ### Uso recomendado de tuplas
#
#
# Agrupar elementos que deben ir juntos
#
# >>> carta = (5, ‘corazones’)
#
# >>> triangulo = ((5, 1), (2, 4), (-2, 0))
#
# >>> alumno = (‘Juan’, ‘Perez’, ‘11111111-1’)
#
# Representar fechas
#
# >>> (2020, 4, 1) > (2020, 3, 1)
#
# True

# %% [markdown]
# ### Listas de tuplas
# autos = [(‘Subaru’, ‘Forester’, 2019), (‘Kia’, ‘Sportage’, 2020), (‘Hyundai’, ‘Santa fe’, 2018), (‘Chevrolet’, ‘Captiva’, 2010), (‘Renault’, ‘Duster’, 2020), ]
#
# for marca, modelo, anio in autos:
#
#  print(modelo, 'del anio', anio)
#
# for i in range(len(autos)):
#
# print(autos[i][1] ‘del anio’, autos[i][2])

# %% [markdown]
# ### Trabajo grupal – Ejercicio #1
# Considere las siguientes asignaciones:
#
# >>> a = (2, 10, 1991)
#
#
# >>> b = (25, 12, 1990)
#
#
# >>> c = (‘Donald’, True, b)
#
#
# >>> x, y = ((27, 3), 9)
#
#
# >>> z, w = x
#
#
# >>> v = (x, a)
#
#
#
# Sin usar el computador, indiquen en grupo cuál es el resultado y el tipo de las siguientes expresiones. Luego,
# verifique en el computador.
#
# 1. a < b 7. a + b[1:5]
# 2. y + w 8. (a + b)[1:5]
# 3. x + a 9. str(a[2]) + str(b[2])
# 4. len(v) 10. str(a[2] + b[2])
# 5. v[1][1] 11. str((a + b)[2])
# 6. c[0] 12. str(a + b)[2][0]

# %%
a = (2, 10, 1991)

b = (25, 12, 1990)

c = ('Donald', True, b)

x, y = ((27, 3), 9)

z, w = x

v = (x, a)

# %%
a < b
# Out:
# True

# %%
z
# Out:
# 27

# %%
y
# Out:
# 9

# %%
w
# Out:
# 3

# %%
y + w
# Out:
# 12

# %%
a
# Out:
# (2, 10, 1991)

# %%
x
# Out:
# (27, 3)

# %%
x+a
# Out:
# (27, 3, 2, 10, 1991)

# %%
len(v)
# Out:
# 2

# %%
v[1][1]
# Out:
# 10

# %%
c[0]
# Out:
# 'Donald'

# %%
b
# Out:
# (25, 12, 1990)

# %%
a + b[1:5]
# Out:
# (2, 10, 1991, 12, 1990)

# %%
(a + b)[1:5]
# Out:
# (10, 1991, 25, 12)

# %%
str(a[2]) + str(b[2])
# Out:
# '19911990'

# %%
str(a[2] + b[2])
# Out:
# '3981'

# %%
str((a + b)[2])
# Out:
# '1991'

# %%
str(a + b)[2][0]
# Out:
# ','

# %%
str(a + b)[2]
# Out:
# ','

# %%
str(a + b)
# Out:
# '(2, 10, 1991, 25, 12, 1990)'

# %% [markdown]
# ### Trabajo grupal – Ejercicio #2
#
# Un supermercado utiliza las siguientes estructuras de datos para manejar su
# inventario. Las estructuras se encuentran en el archivo supermercado.py.
#
# Basado en esas estructuras (listas de tuplas), desarrolle las siguientes
# funciones:
#
# >>> producto_mas_caro(productos)
#
# ‘Vuvuzela’
# >>> valor_total_bodega(productos)
#
# 1900570
# >>> ingreso_total_por_ventas(itemes, productos)
#
# 13944

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/My Drive/Colab Notebooks/supermercado_c4.py"

# %%
def producto_mas_caro(productos):
  maxprecio=0
  for id,producto,precio,cant in productos:
    if precio>maxprecio:
      maxprecio = precio
      maxprod = producto
  return maxprod

# %%
def producto_mas_caro_v2(productos):
  lista =[]
  for id,producto,precio,cant in productos:
      lista.append((precio,producto))
  lista.sort()
  return lista[-1][1]

# %%
producto_mas_caro_v2(productos)
# Out:
# 'Vuvuzela'

# %%
def valor_total_bodega(productos):
  suma=0
  for id,producto,precio,cant in productos:
    suma += precio*cant

  return suma

# %%
valor_total_bodega(productos)
# Out:
# 1900570

# %%
def ingreso_total_por_ventas(itemes, productos):
  suma=0
  for boleta,id,cantvend in itemes:
    for id2,producto,precio,cant in productos:
      if id==id2:
        suma += cantvend*precio
  return suma

# %%
ingreso_total_por_ventas(itemes, productos)
# Out:
# 13944

# %% [markdown]
# # Trabajo post-clase–Ejercicio #1
#
# Considerando las estructuras del ejercicio anterior (supermercado), desarrolle las siguientes funciones:
#
#
# >>> producto_con_mas_ingresos(itemes, productos)
#
# ‘Arroz’
#
# >>> cliente_que_mas_pago(itemes, productos, clientes)
#
# ‘VictorGamonal’
#
# >>> ingreso_total_por_ventas(itemes, productos)
#
# 13944
#
# >>> total_ventas_del_mes(2010, 10, itemes, productos, ventas)
#
# 4160
#
# >>> fecha_ultima_venta_producto(47470, itemes, ventas)
#
# (2010, 10, 13)

# %%
def producto_con_mas_ingresos(itemes, productos):
  max_i_p=0
  ingreso_producto = 0
  for boleta,id,cantvend in itemes:
    for id2,producto,precio,cant in productos:
      if id==id2:
        ingreso_producto = cantvend * precio
        if ingreso_producto > max_i_p:
          max_i_p = ingreso_producto
          nom_max_i_p = producto
  return nom_max_i_p

# %%
producto_con_mas_ingresos(itemes, productos)
# Out:
# 'Arroz'

# %%
def cliente_que_mas_pago(itemes, productos, clientes):
  max_i_p=0
  suma_ventas = 0
  for rut, nombre in clientes:
    for num_boleta,fecha_venta, rut_cliente in ventas:
      for boleta,id,cantvend in itemes:
        for id2,producto,precio,cant in productos:
          if id==id2 and rut==rut_cliente and num_boleta==boleta:
            suma_ventas += cantvend * precio
            if suma_ventas > max_i_p:
              max_i_p = suma_ventas
              nom_max_i_p = nombre
  return nom_max_i_p

# %%
cliente_que_mas_pago(itemes, productos, clientes)
# Out:
# 'Victor Gamonal'

# %%
def ingreso_total_por_ventas(itemes, productos):
  max_i_p=0
  ingreso_total = 0
  for boleta,id,cantvend in itemes:
    for id2,producto,precio,cant in productos:
      if id==id2:
        ingreso_total += cantvend * precio
  return ingreso_total

# %%
ingreso_total_por_ventas(itemes, productos)
# Out:
# 13944

# %%
def total_ventas_del_mes(y, m, itemes, productos, ventas):
  max_i_p=0
  suma_ventas = 0
  for rut, nombre in clientes:
    for num_boleta,fecha_venta, rut_cliente in ventas:
      for boleta,id,cantvend in itemes:
        for id2,producto,precio,cant in productos:
          if id==id2 and rut==rut_cliente and num_boleta==boleta and fecha_venta[0]==y and fecha_venta[1]==m:
            suma_ventas += cantvend * precio
  return suma_ventas

# %%
total_ventas_del_mes(2010, 10, itemes, productos, ventas)
# Out:
# 4160

# %%
def fecha_ultima_venta_producto(a, itemes, ventas):
    fecha_mayor =(0,0,0)
    for num_boleta,fecha_venta, rut_cliente in ventas:
      for boleta,id,cantvend in itemes:
          if num_boleta==boleta and id==a: 
            if fecha_venta>fecha_mayor:
              fecha_mayor = fecha_venta
    return fecha_mayor

# %%
fecha_ultima_venta_producto(47470, itemes, ventas)
# Out:
# (2010, 10, 13)

# %%
def fecha_ultima_venta_producto2(a, itemes, ventas):
    lista_fechas=[]
    for boleta,id,cantvend in itemes:
      if id==a:
        for num_boleta,fecha_venta, rut_cliente in ventas:
          if boleta==num_boleta:
            lista_fechas.append(fecha_venta)
    lista_fechas.sort(reverse=True)
    return lista_fechas[0]

# %%
fecha_ultima_venta_producto2(47470, itemes, ventas)
# Out:
# (2010, 10, 13)
