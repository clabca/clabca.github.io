# %% [markdown]
# # **Obtención y preparación de datos**
#
# # OD27. Proyecto Final
#
# Normalmente, los proyectos de ciencia de datos, comienzan con estadísticas descriptivas para tener una idea de las propiedades del conjunto de datos que se está trabajando. Afortunadamente, es fácil obtener estas estadísticas con las estructuras de datos de **Pandas**.

# %% [markdown]
# ## <font color='blue'>**Estadística Descriptiva con la Base de Datos Iris**</font>
#
# En este proyecto, deberán implemnetar el cálculo de varias estadísticas descriptivas para el clásico <a href="https://en.wikipedia.org/wiki/Iris_flower_data_set">conjunto de datos de iris</a>.
#
# El siguiente código, carga los paquetes necesarios y también el conjunto de datos iris.
#
# `load_iris()` carga en un objeto que contiene el conjunto de datos de iris.

# %%
import pandas as pd
import numpy as np

from pandas import DataFrame
from sklearn.datasets import load_iris

iris_obj = load_iris()

# %% [markdown]
# Obtendremos un objeto del tipo __Bunch__, el cual es un contenedor de datos a los cuales se accede a través de _llaves_, de forma similar que en un diccionario de Python.

# %%
type(iris_obj)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris_obj.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(type(iris_obj['data']), '\n')
iris_obj['data']
# Out:
# <class 'numpy.ndarray'>
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
# ...

# %% [markdown]
# ### <font color='green'>Actividad 1</font>
#
# Basado en la estructura del objeto **iris_obj**, convierta este en un dataframe.

# %%
# Tu código aquí ...

import pandas as pd
from sklearn.datasets import load_iris

iris_obj = load_iris()  # Carga de objeto que contiene el conjunto de datos de iris
df = pd.DataFrame(data=iris_obj.data, columns=iris_obj.feature_names)
#df.head() solo muestra las 5 primeras filas
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# <font color='green'>Fin Actividad 1</font>

# %% [markdown]
# ### <font color='green'>Actividad 2</font>
#
# 1. Reemplace los valores de la columna "species" por los siguientes valores:
#   * "setosa" = 0
#   * "versicolor" = 1
#   * "virginica" = 2
#
# 2. Agrupe las muestras por especies
# 3. Sin usar el método `describe` calcule los estadísticos básicos de la muestra:
#   * cantidad de elementos no nulos
#   * media
#   * varianza
#   * Desviación estándar
#   * Percentiles y cuartiles
#   * Rango inter-cuartílico
#   * Valores máximos y mínimos
#   * Rango (diferencia entre el máximo y el mínimo)
# 4. Repita algunos de los análisis anteriores, pero muestre sus resultados por columnas y especies.
# 5. Compare sus resultados usando el metodo `describe` por columnas y por especies
# 6. Generar una tabla multi-indice por "especies" y "ancho del pétalo" y que de cuenta de la suma de los valores de cada clase

# %%
# Tu código aquí ...

# 1. Reemplace los valores de la columna "species" por los siguientes valores: "setosa" = 0; "versicolor" = 1; "virginica" = 2

# Añadimos columna 'species' y sus valores con replace
# El método replace reemplazar valores en un DataFrame o Serie con nuevos valores.

df['species'] = iris_obj.target
df['species'].replace({0: 'setosa', 1: 'versicolor', 2: 'virginica'}, inplace=True)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
# 2. Agrupe las muestras por especies
especies = df.groupby('species')

# print(especies.mean())

# %%
# 3. Sin usar describe, calcule los estadísticos básicos de la muestra:
#   - cantidad de elementos no nulos         - Percentiles y cuartiles
#   - media                                  - Rango inter-cuartílico
#   - varianza                               - Valores máximos y mínimos
#   - Desviación estándar                    - Rango (diferencia entre el máximo y el mínimo)

# iris_obj = load_iris()  # Carga del conjunto de datos de iris
# df = pd.DataFrame(data=iris_obj.data, columns=iris_obj.feature_names)

print("Cantidad de elementos no nulos\n", df.count())
print("\nMedia\n", df.mean(numeric_only=True))
print("\nVarianza\n", df.var(numeric_only=True))
print("\nDesviación estándar\n", df.std(numeric_only=True))
perc = df.quantile([0.25, 0.5, 0.75], numeric_only=True)
print("\nPercentiles y cuartiles\n", perc)
print("\nRango inter-cuartílico\n", perc.loc[0.75] - perc.loc[0.25])
print("\nValores máximos\n", df.max())
print("\nValores mínimos\n", df.min())

# rango = df.max() - df.min() No funcionó, ya que hay valores no númericos, así que separamos los enteros
solo_int = df.select_dtypes(include=[float, int])
print("\nRango (diferencia entre el máximo y el mínimo)\n", solo_int.max() - solo_int.min())
# Out:
# Cantidad de elementos no nulos
#  sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# species              150
# dtype: int64
#
# Media
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Varianza
#  sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64
#
# Desviación estándar
#  sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64
#
# Percentiles y cuartiles
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0.25                5.1               2.8               1.60               0.3
# 0.50                5.8               3.0               4.35               1.3
# ...

# %%
# 4. Repita algunos de los análisis anteriores, pero muestre sus resultados por columnas y especies.

# Opción 1
print("\nMedia", df.groupby('species').mean(numeric_only=True))
print("\nVarianza", df.groupby('species').var(numeric_only=True))
print("\nDesviación estándar", df.groupby('species').std(numeric_only=True))
print("\nPercentiles y cuartiles", df.groupby('species').quantile([0.25, 0.5, 0.75], numeric_only=True))
# Out:
# Media             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# Varianza             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa               0.124249          0.143690           0.030159
# versicolor           0.266433          0.098469           0.220816
# virginica            0.404343          0.104004           0.304588
#
#             petal width (cm)
# species
# setosa              0.011106
# versicolor          0.039106
# virginica           0.075433
#
# Desviación estándar             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# ...

# %%
# Opción 2 visualización
Media = df.groupby('species').mean(numeric_only=True)
Media
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
# 5. Compare sus resultados usando el metodo `describe` por columnas y por especies

# Resultados por columnas
resul_columnas = df.describe()
resul_columnas
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Resultados por especies
resul_especies = especies.describe() #Agrupamos por especies en el punto 2 de la actividad 1.
resul_especies
# Out:
#            sepal length (cm)                                              \
#                        count   mean       std  min    25%  50%  75%  max
# species
# setosa                  50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor              50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica               50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal width (cm)         ... petal length (cm)       \
#                       count   mean  ...               75%  max
# species                             ...
# setosa                 50.0  3.428  ...             1.575  1.9
# versicolor             50.0  2.770  ...             4.600  5.1
# virginica              50.0  2.974  ...             5.875  6.9
#
#            petal width (cm)
#                       count   mean       std  min  25%  50%  75%  max
# species
# setosa                 50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# ...

# %%
# 6. Generar una tabla multi-indice por "especies" y "ancho del pétalo" y que de cuenta de la suma de los valores de cada clase

# multi_indice = df.groupby(['species', df['petal width (cm)']])['petal width (cm)'].sum()                # Falta generar columna
# multi_indice = df.groupby(['species', df['petal width (cm)']])['petal width (cm)'].sum().reset_index()  # No funciono
multi_indice = df.groupby(['species', df['petal width (cm)']]).size().reset_index(name='Cantidad')
multi_indice
# Out:
#        species  petal width (cm)  Count
# 0       setosa               0.1      5
# 1       setosa               0.2     29
# 2       setosa               0.3      7
# 3       setosa               0.4      7
# 4       setosa               0.5      1
# 5       setosa               0.6      1
# 6   versicolor               1.0      7
# 7   versicolor               1.1      3
# 8   versicolor               1.2      5
# 9   versicolor               1.3     13
# 10  versicolor               1.4      7
# 11  versicolor               1.5     10
# 12  versicolor               1.6      3
# 13  versicolor               1.7      1
# 14  versicolor               1.8      1
# 15   virginica               1.4      1
# 16   virginica               1.5      2
# 17   virginica               1.6      1
# 18   virginica               1.7      1
# 19   virginica               1.8     11
# 20   virginica               1.9      5
# 21   virginica               2.0      6
# ...

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# ## <font color='blue'>**Análisis de Datos con Base de Datos Titanic**</font>
#
# Para este probleme utilizaremos la base de datos "_titanic_". Para cargarla debe usar los siguientes comandos:
#
# ```
# import seaborn as sns
# titanic = sns.load_dataset("titanic")
# titanic.head(5)
# ```
# Considere sólo las siguientes variables: _survived_, _pclass_, _sex_, _age_, _fare_ y _embarked_.

# %% [markdown]
# ### <font color='green'>Actividad 3</font>
#
# 1. Reemplace los valores faltantes para la columna edad por el valor promedio de la muestra.
# 2. Elimine cualquier otra fila en la que falten datos

# %%
# Tu código aquí ...

import pandas as pd
import numpy as np
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Verificamos el numero de datos nulos por columna y el tamaño del df.

print(titanic.isnull().sum())
print()
print(titanic.shape)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# (891, 15)

# %%
# 1. Reemplace los valores faltantes para la columna edad por el valor promedio de la muestra.

promedio = titanic['age'].mean()
titanic['age'].fillna(promedio, inplace=True)

# %%
# 2. Elimine cualquier otra fila en la que falten datos

titanic.dropna(inplace=True)

# %%
# verificamos que el nuevo df no contenga datos nulos, su tamaño y el número de sobrevivientes para este df

print('Número de sobrevivientes', titanic['survived'].sum())
print()
titanic.info()
# Out:
# Número de sobrevivientes 134
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     201 non-null    int64
#  1   pclass       201 non-null    int64
#  2   sex          201 non-null    object
#  3   age          201 non-null    float64
#  4   sibsp        201 non-null    int64
#  5   parch        201 non-null    int64
#  6   fare         201 non-null    float64
#  7   embarked     201 non-null    object
#  8   class        201 non-null    category
#  9   who          201 non-null    object
#  10  adult_male   201 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  201 non-null    object
#  13  alive        201 non-null    object
#  14  alone        201 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 20.1+ KB

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>

# %% [markdown]
# ### <font color='green'>Actividad 4</font>
#
# 1. Entregar la información correspondiente a la la tasa de supervivencia promedio agrupada por sexo y clase del pasajero.
# 2. Genere una tabla que muestre la cantidad de personas agrupadas por sexo y clase.
# 3. Muestre la misma información del punto 1, pero la cantidad de sobrevivientes.

# %%
# Tu código aquí ...

# 1. Entregar la información correspondiente a la la tasa de supervivencia promedio agrupada por sexo y clase del pasajero.

tasa_supervivencia = titanic.groupby(['sex', 'class'])['survived'].mean().reset_index()
tasa_supervivencia
# Out:
#       sex   class  survived
# 0  female   First  0.962025
# 1  female  Second  0.900000
# 2  female   Third  0.666667
# 3    male   First  0.414894
# 4    male  Second  0.666667
# 5    male   Third  0.333333

# %%
# 2. Genere una tabla que muestre la cantidad de personas agrupadas por sexo y clase.

tabla_cantidad_personas = titanic.groupby(['sex', 'class']).size().reset_index(name='cantidad')
tabla_cantidad_personas
# Out:
#       sex   class  cantidad
# 0  female   First        79
# 1  female  Second        10
# 2  female   Third         6
# 3    male   First        94
# 4    male  Second         6
# 5    male   Third         6

# %%
# 3. Muestre la misma información del punto 1, pero la cantidad de sobrevivientes

sobrevivientes = titanic.groupby(['sex', 'class'])['survived'].sum().reset_index(name='Sobrevivientes')
sobrevivientes
# Out:
#       sex   class  Sobrevivientes
# 0  female   First              76
# 1  female  Second               9
# 2  female   Third               4
# 3    male   First              39
# 4    male  Second               4
# 5    male   Third               2

# %% [markdown]
# Hasta ahora hemos examinado las tasas de supervivencia según el sexo y la clase de pasajeros. Otro factor que podría haber influido en la supervivencia es la edad. **¿Los niños varones tenían tanta probabilidad de morir como las mujeres en general?** Podemos investigar esta pregunta mediante la indexación múltiple, o pivotando en más de dos variables, agregando otro índice.
#
# Divida la información de la columna "age" en intervalos, creando así una nueva categoría que se puede utilizar para agrupar. Divida el conjunto en intervalos de (0, 12], (12, 18] y (18, 80].
#
# 4. Genere la tabla que le ayude a responder la pregunta anterior (considerando los rangos definidos).
# 5. Para una mejor interpretación de la información anterior, genere una tabla con el número de entradas por cada grupo.

# %%
# Tu código aquí ...

# 4. Genere la tabla que le ayude a responder la pregunta anterior (considerando los rangos definidos).

bins = [0, 12, 18, 80]                        # límites de los intervalos
labels = ['(0, 12]', '(12, 18]', '(18, 80]']  # etiquetas para los intervalos

# pd.cut() para crear la columna "intervalos_edad"
titanic['intervalos_edad'] = pd.cut(titanic['age'], bins=bins, labels=labels, right=False)
titanic.reset_index(drop=True, inplace=True)
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         1       1  female  38.0      1      0  71.2833        C  First
# 1         1       1  female  35.0      1      0  53.1000        S  First
# 2         0       1    male  54.0      0      0  51.8625        S  First
# 3         1       3  female   4.0      1      1  16.7000        S  Third
# 4         1       1  female  58.0      0      0  26.5500        S  First
#
#      who  adult_male deck  embark_town alive  alone intervalos_edad
# 0  woman       False    C    Cherbourg   yes  False        (18, 80]
# 1  woman       False    C  Southampton   yes  False        (18, 80]
# 2    man        True    E  Southampton    no   True        (18, 80]
# 3  child       False    G  Southampton   yes  False         (0, 12]
# 4  woman       False    C  Southampton   yes   True        (18, 80]

# %%
# 5. Para una mejor interpretación de la información anterior, genere una tabla con el número de entradas por cada grupo.

grupo_edad = titanic.groupby('intervalos_edad')['survived'].count().reset_index(name='numero_de_entradas')
grupo_edad
# Out:
#   intervalos_edad  numero_de_entradas
# 0         (0, 12]                  11
# 1        (12, 18]                   8
# 2        (18, 80]                 181

# %% [markdown]
# Pandas también admite la indexación múltiple en las columnas. Como ejemplo, considere el precio de los boletos de un pasajero. Esta es otra característica continua que se puede discretizar. Divida los precios en 2 cuantiles iguales (baratos y caros). Algunos de los grupos resultantes podrían estar vacíos; para mejorar la legibilidad de la tabla use un guión en las casillas vacías.
#
# 6. Genere una tabla que nos permita ver el efecto del precio de los tickets.

# %%
# Tu código aquí ...

# 6. Genere una tabla que nos permita ver el efecto del precio de los tickets.

# Dividir los precios en 2 cuantiles iguales (baratos y caros)
titanic['precio_interval'] = pd.qcut(titanic['fare'], q=2, labels=['Barato', 'Caro'])

# Utilizar pd.pivot_table() para analizar el efecto del precio del boleto
tabla_pivote = pd.pivot_table(titanic, index=['class', 'sex'], columns=['precio_interval'], values='survived', aggfunc='mean', fill_value='-')
tabla_pivote
# Out:
# precio_interval    Barato      Caro
# class  sex
# First  female    0.947368  0.966667
#        male      0.407407     0.425
# Second female    0.900000         -
#        male      0.666667         -
# Third  female    0.666667         -
#        male      0.333333         -

# %%
# CASO 2

titanic['precio_interval_3'] = pd.qcut(titanic['fare'], q=2, labels=['Barato', 'Caro'])
tabla_pivote = pd.pivot_table(titanic, index=['deck', 'sex'], columns=['precio_interval_3'], values='survived', aggfunc='mean', fill_value='----')
tabla_pivote
# Out:
# precio_interval_3    Barato      Caro
# deck sex
# A    female        1.000000      ----
#      male          0.333333       1.0
# B    female        1.000000       1.0
#      male          0.125000  0.583333
# C    female        0.833333  0.904762
#      male          0.437500      0.25
# D    female        1.000000       1.0
#      male          0.444444       0.5
# E    female        0.875000       1.0
#      male          0.692308      0.25
# F    female        1.000000      ----
#      male          0.375000      ----
# G    female        0.500000      ----

# %% [markdown]
# <font color='green'>Fin Actividad 4</font>

# %% [markdown]
# ### <font color='green'>Actividad 5</font>
#
# ### Análisis de una Hipótesis
#
# Supongamos que alguien afirma que la ciudad desde la que se embarcó un pasajero tuvo una gran influencia en la tasa de supervivencia del pasajero. Investigue esta afirmación.
#
# 1. Verifique las tasas de supervivencia de los pasajeros según el lugar desde donde se embarcaron (indicadas en la columna "embarked").
#
# 2. Cree una tabla dinámica para examinar las tasas de supervivencia según el lugar de embarque y el género.
#
# 3. ¿Qué le sugieren estas tablas sobre la importancia de dónde se embarcaron las personas para influir en su tasa de supervivencia? Examine el contexto del problema y explique lo que cree que esto realmente significa.
#
# 4. Investigue la afirmación más a fondo con al menos dos tablas dinámicas más, explorando otros criterios (por ejemplo, clase, edad, etc.). Explique cuidadosamente sus conclusiones.

# %%
# Tu código aquí ...

# 1. Verifique las tasas de supervivencia de los pasajeros según el lugar desde donde se embarcaron (indicadas en la columna "embarked").

import seaborn as sns
import matplotlib.pyplot as plt

sobreviviente_por_embarque = titanic.groupby('embarked')['survived'].mean().reset_index()

sns.barplot(x='embarked', y='survived', data=sobreviviente_por_embarque)
plt.title('Tasa de Supervivencia por Ciudad de Embarque')
plt.xlabel('Ciudad de Embarque')
plt.ylabel('Tasa de Supervivencia')
plt.show()

# %% [markdown]
# Las letras que etiquetan las categorías de la variable 'embarked' corresponden a las ciudades donde la gente se embarcó en el Titanic:
#
# * Cherbourg
# * Queenstown
# * Southampton

# %%
# Tu código aquí ...

sobreviviente_embarque = titanic.groupby('embarked')['survived'].mean()

print(sobreviviente_embarque)
# Out:
# embarked
# C    0.753623
# Q    0.500000
# S    0.625000
# Name: survived, dtype: float64

# %%
# 2. Cree una tabla dinámica para examinar las tasas de supervivencia según el lugar de embarque y el género.

pivot_table = pd.pivot_table(titanic, values='survived', index='embark_town', columns='sex', aggfunc='mean')
pivot_table
# Out:
# sex            female      male
# embark_town
# Cherbourg    0.972973  0.500000
# Queenstown   1.000000  0.000000
# Southampton  0.910714  0.402778

# %%
# 3. ¿Qué le sugieren estas tablas sobre la importancia de dónde se embarcaron las personas para influir en su tasa de supervivencia?
#    Examine el contexto del problema y explique lo que cree que esto realmente significa

# %% [markdown]
# Al examinar las tablas que muestran las tasas de supervivencia según el lugar de embarque y el género, se pueden obtener algunas conclusiones e insights relevantes:
#
# Variación en la Tasa de Supervivencia: Las tablas indicarán si hay una variación en las tasas de supervivencia promedio entre diferentes lugares de embarque y géneros. Si observas diferencias significativas en las tasas de supervivencia, esto podría sugerir que el lugar de embarque y el género tienen algún tipo de influencia en la supervivencia de los pasajeros.
#
# Contexto Histórico: Para comprender completamente estas diferencias, es importante considerar el contexto histórico y las circunstancias específicas del hundimiento del Titanic. Por ejemplo, es posible que ciertos lugares de embarque hayan tenido una proporción diferente de pasajeros de primera, segunda y tercera clase, lo que podría influir en la tasa de supervivencia debido a la priorización de los pasajeros de primera clase durante el rescate.
#
# Otros Factores: Además del lugar de embarque y el género, hay otros factores que también pueden haber influido en la tasa de supervivencia, como la clase de pasajero, la edad, la disponibilidad de botes salvavidas en diferentes áreas del barco y la proximidad a las vías de evacuación.

# %%
# 4. Investigue la afirmación más a fondo con al menos dos tablas dinámicas más, explorando otros criterios (por ejemplo, clase, edad, etc.).
#    Explique cuidadosamente sus conclusiones.

# Tabla Dinámica 1: Tasa de Supervivencia por Intervalo de edad y Clase de Pasajero

tabla_class_interv_edad = pd.pivot_table(titanic, values='survived', index='intervalos_edad', columns='class', aggfunc='mean', fill_value='-')
tabla_class_interv_edad
# Out:
# class              First Second     Third
# intervalos_edad
# (0, 12]          0.75000    1.0  0.666667
# (12, 18]         1.00000      -         -
# (18, 80]         0.64375   0.75  0.444444

# %% [markdown]
# Esta tabla mostrará la tasa de supervivencia promedio desglosada por los intervalos de edad ('(',12]', '(12,18]', '(18,80]') y la clase ('First', 'Second', 'Third'). Esto nos permitirá examinar si la tasa de supervivencia varía según los intervalos de edad y la clase.

# %%
# Tabla Dinámica 2: Tasa de Supervivencia por Embarque y grupos de edad

# Creamos los grupos de edad
bins = [0, 18, 30, 50, 100]
labels = ['0-17', '18-29', '30-49', '50+']
titanic['age_group'] = pd.cut(titanic['age'], bins=bins, labels=labels)

tabla_age_embarked = pd.pivot_table(titanic, values='survived', index='embarked', columns='age_group', aggfunc='mean', fill_value='-')
tabla_age_embarked
# Out:
# age_group      0-17     18-29     30-49       50+
# embarked
# C          0.833333  0.826087  0.750000  0.583333
# Q                 -  0.500000  0.500000         -
# S          0.882353  0.600000  0.627451      0.45

# %% [markdown]
# Esta tabla mostrará la tasa de supervivencia promedio desglosada por lugar de embarque ('C', 'Q', 'S') y grupos de edad ('0-17', '18-29', '30-49', '50+'). Esto nos permitirá examinar si la tasa de supervivencia varía según el lugar de embarque y la edad de los pasajeros.

# %% [markdown]
# <font color='green'>Fin Actividad 5</font>
